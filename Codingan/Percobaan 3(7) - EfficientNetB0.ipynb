# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report

# %%
image_dir = Path(r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset")

# %% [markdown]
# Buat File Dataframe

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

images = pd.concat([filepaths, labels], axis=1)

category_samples = []
for category in images['Label'].unique():
    category_slice = images.query("Label == @category")
    # Ambil sampel dari setiap kategori dengan maksimum 600 gambar
    category_samples.append(category_slice.sample(min(6000, len(category_slice)), random_state=1, replace=False))

image_df = pd.concat(category_samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                                Filepath      Label
# 0     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 1     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 2     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...  Sop Konro
# 3     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 4     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# ...                                                 ...        ...
# 6793  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6794  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
# 6795  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 6796  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6797  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
#
# [6798 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# Label
# Gogos        1133
# Sop Konro    1133
# Kapurung     1133
# Buras        1133
# Dangkot      1133
# Sokko        1133
# Name: count, dtype: int64

# %%
train_dir = r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\train'
val_dir =r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\val'
test_dir=r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test'

# %% [markdown]
# Buat Train Generator

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_images = train_generator.flow_from_directory(
    directory=train_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='training'
)

val_images = train_generator.flow_from_directory(
    directory=val_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='validation'
)

test_images = test_generator.flow_from_directory(
    directory=test_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 4758 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.

# %% [markdown]
# Modelling

# %%
pretrained_model = EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='swish')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='swish')(x)

outputs = tf.keras.layers.Dense(6, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)


#print(model.summary())

# %% [markdown]
# Training

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
model.compile(
    optimizer='adagrad',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc'),
        f1_score,
    ]
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=300,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/300
# c:\Program Files\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.8333 - auc: 0.6201 - f1_score: 0.0000e+00 - loss: 1.7429 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8333 - val_auc: 0.8438 - val_f1_score: 0.0000e+00 - val_loss: 1.5835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.8335 - auc: 0.8723 - f1_score: 0.0016 - loss: 1.5324 - precision: 0.4267 - recall: 8.3718e-04 - val_accuracy: 0.8368 - val_auc: 0.9221 - val_f1_score: 0.0393 - val_loss: 1.3668 - val_precision: 1.0000 - val_recall: 0.0206
# Epoch 3/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.8383 - auc: 0.9258 - f1_score: 0.0584 - loss: 1.3212 - precision: 0.9421 - recall: 0.0312 - val_accuracy: 0.8503 - val_auc: 0.9461 - val_f1_score: 0.1862 - val_loss: 1.1519 - val_precision: 0.9643 - val_recall: 0.1059
# Epoch 4/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.8535 - auc: 0.9461 - f1_score: 0.2166 - loss: 1.1194 - precision: 0.9640 - recall: 0.1259 - val_accuracy: 0.8750 - val_auc: 0.9622 - val_f1_score: 0.4006 - val_loss: 0.9587 - val_precision: 0.9740 - val_recall: 0.2569
# Epoch 5/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.8788 - auc: 0.9609 - f1_score: 0.4334 - loss: 0.9288 - precision: 0.9580 - recall: 0.2851 - val_accuracy: 0.9060 - val_auc: 0.9730 - val_f1_score: 0.6087 - val_loss: 0.7995 - val_precision: 0.9847 - val_recall: 0.4431
# Epoch 6/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9112 - auc: 0.9718 - f1_score: 0.6385 - loss: 0.7742 - precision: 0.9689 - recall: 0.4825 - val_accuracy: 0.9304 - val_auc: 0.9792 - val_f1_score: 0.7374 - val_loss: 0.6762 - val_precision: 0.9729 - val_recall: 0.5990
# Epoch 7/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9292 - auc: 0.9753 - f1_score: 0.7354 - loss: 0.6791 - precision: 0.9548 - recall: 0.6036 - val_accuracy: 0.9436 - val_auc: 0.9830 - val_f1_score: 0.8006 - val_loss: 0.5826 - val_precision: 0.9617 - val_recall: 0.6892
# Epoch 8/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9423 - auc: 0.9805 - f1_score: 0.7983 - loss: 0.5831 - precision: 0.9438 - recall: 0.6952 - val_accuracy: 0.9516 - val_auc: 0.9856 - val_f1_score: 0.8353 - val_loss: 0.5138 - val_precision: 0.9514 - val_recall: 0.7480
# Epoch 9/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 996ms/step - accuracy: 0.9469 - auc: 0.9815 - f1_score: 0.8203 - loss: 0.5340 - precision: 0.9302 - recall: 0.7369 - val_accuracy: 0.9593 - val_auc: 0.9874 - val_f1_score: 0.8661 - val_loss: 0.4610 - val_precision: 0.9509 - val_recall: 0.7971
# Epoch 10/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9517 - auc: 0.9847 - f1_score: 0.8395 - loss: 0.4810 - precision: 0.9297 - recall: 0.7679 - val_accuracy: 0.9627 - val_auc: 0.9885 - val_f1_score: 0.8798 - val_loss: 0.4221 - val_precision: 0.9480 - val_recall: 0.8216
# Epoch 11/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 995ms/step - accuracy: 0.9584 - auc: 0.9870 - f1_score: 0.8658 - loss: 0.4299 - precision: 0.9310 - recall: 0.8107 - val_accuracy: 0.9649 - val_auc: 0.9897 - val_f1_score: 0.8866 - val_loss: 0.3893 - val_precision: 0.9448 - val_recall: 0.8382
# Epoch 12/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 148s 986ms/step - accuracy: 0.9605 - auc: 0.9884 - f1_score: 0.8725 - loss: 0.4040 - precision: 0.9355 - recall: 0.8197 - val_accuracy: 0.9667 - val_auc: 0.9903 - val_f1_score: 0.8940 - val_loss: 0.3651 - val_precision: 0.9444 - val_recall: 0.8500
# Epoch 13/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 987ms/step - accuracy: 0.9623 - auc: 0.9884 - f1_score: 0.8796 - loss: 0.3828 - precision: 0.9331 - recall: 0.8334 - val_accuracy: 0.9672 - val_auc: 0.9910 - val_f1_score: 0.8963 - val_loss: 0.3445 - val_precision: 0.9408 - val_recall: 0.8569
# Epoch 14/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 982ms/step - accuracy: 0.9609 - auc: 0.9886 - f1_score: 0.8765 - loss: 0.3727 - precision: 0.9208 - recall: 0.8375 - val_accuracy: 0.9686 - val_auc: 0.9916 - val_f1_score: 0.9013 - val_loss: 0.3278 - val_precision: 0.9433 - val_recall: 0.8637
# Epoch 15/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 148s 980ms/step - accuracy: 0.9643 - auc: 0.9901 - f1_score: 0.8877 - loss: 0.3437 - precision: 0.9298 - recall: 0.8500 - val_accuracy: 0.9698 - val_auc: 0.9917 - val_f1_score: 0.9058 - val_loss: 0.3151 - val_precision: 0.9390 - val_recall: 0.8755
# Epoch 16/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 987ms/step - accuracy: 0.9636 - auc: 0.9898 - f1_score: 0.8862 - loss: 0.3380 - precision: 0.9200 - recall: 0.8558 - val_accuracy: 0.9703 - val_auc: 0.9921 - val_f1_score: 0.9078 - val_loss: 0.3038 - val_precision: 0.9365 - val_recall: 0.8814
# Epoch 17/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 990ms/step - accuracy: 0.9664 - auc: 0.9916 - f1_score: 0.8947 - loss: 0.3163 - precision: 0.9329 - recall: 0.8605 - val_accuracy: 0.9706 - val_auc: 0.9924 - val_f1_score: 0.9089 - val_loss: 0.2937 - val_precision: 0.9375 - val_recall: 0.8824
# Epoch 18/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9677 - auc: 0.9922 - f1_score: 0.8994 - loss: 0.3014 - precision: 0.9301 - recall: 0.8718 - val_accuracy: 0.9716 - val_auc: 0.9927 - val_f1_score: 0.9117 - val_loss: 0.2848 - val_precision: 0.9397 - val_recall: 0.8863
# Epoch 19/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 991ms/step - accuracy: 0.9698 - auc: 0.9913 - f1_score: 0.9065 - loss: 0.3005 - precision: 0.9346 - recall: 0.8803 - val_accuracy: 0.9717 - val_auc: 0.9928 - val_f1_score: 0.9125 - val_loss: 0.2791 - val_precision: 0.9380 - val_recall: 0.8892
# Epoch 20/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 991ms/step - accuracy: 0.9704 - auc: 0.9928 - f1_score: 0.9080 - loss: 0.2847 - precision: 0.9378 - recall: 0.8809 - val_accuracy: 0.9722 - val_auc: 0.9931 - val_f1_score: 0.9135 - val_loss: 0.2714 - val_precision: 0.9390 - val_recall: 0.8912
# Epoch 21/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 995ms/step - accuracy: 0.9718 - auc: 0.9926 - f1_score: 0.9125 - loss: 0.2765 - precision: 0.9392 - recall: 0.8883 - val_accuracy: 0.9727 - val_auc: 0.9933 - val_f1_score: 0.9158 - val_loss: 0.2654 - val_precision: 0.9401 - val_recall: 0.8931
# Epoch 22/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9711 - auc: 0.9932 - f1_score: 0.9108 - loss: 0.2668 - precision: 0.9322 - recall: 0.8911 - val_accuracy: 0.9725 - val_auc: 0.9935 - val_f1_score: 0.9154 - val_loss: 0.2608 - val_precision: 0.9383 - val_recall: 0.8941
# Epoch 23/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9724 - auc: 0.9938 - f1_score: 0.9149 - loss: 0.2602 - precision: 0.9381 - recall: 0.8930 - val_accuracy: 0.9722 - val_auc: 0.9936 - val_f1_score: 0.9144 - val_loss: 0.2580 - val_precision: 0.9363 - val_recall: 0.8941
# Epoch 24/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9706 - auc: 0.9931 - f1_score: 0.9092 - loss: 0.2661 - precision: 0.9339 - recall: 0.8862 - val_accuracy: 0.9732 - val_auc: 0.9937 - val_f1_score: 0.9175 - val_loss: 0.2535 - val_precision: 0.9385 - val_recall: 0.8980
# Epoch 25/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.9734 - auc: 0.9947 - f1_score: 0.9186 - loss: 0.2415 - precision: 0.9406 - recall: 0.8971 - val_accuracy: 0.9734 - val_auc: 0.9940 - val_f1_score: 0.9181 - val_loss: 0.2478 - val_precision: 0.9377 - val_recall: 0.9000
# Epoch 26/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9739 - auc: 0.9942 - f1_score: 0.9198 - loss: 0.2434 - precision: 0.9399 - recall: 0.9009 - val_accuracy: 0.9729 - val_auc: 0.9940 - val_f1_score: 0.9165 - val_loss: 0.2448 - val_precision: 0.9357 - val_recall: 0.8990
# Epoch 27/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9770 - auc: 0.9948 - f1_score: 0.9290 - loss: 0.2268 - precision: 0.9492 - recall: 0.9109 - val_accuracy: 0.9737 - val_auc: 0.9941 - val_f1_score: 0.9189 - val_loss: 0.2415 - val_precision: 0.9378 - val_recall: 0.9020
# Epoch 28/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 996ms/step - accuracy: 0.9721 - auc: 0.9945 - f1_score: 0.9138 - loss: 0.2394 - precision: 0.9348 - recall: 0.8947 - val_accuracy: 0.9740 - val_auc: 0.9942 - val_f1_score: 0.9200 - val_loss: 0.2380 - val_precision: 0.9379 - val_recall: 0.9039
# Epoch 29/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9758 - auc: 0.9944 - f1_score: 0.9259 - loss: 0.2325 - precision: 0.9429 - recall: 0.9099 - val_accuracy: 0.9748 - val_auc: 0.9944 - val_f1_score: 0.9229 - val_loss: 0.2337 - val_precision: 0.9400 - val_recall: 0.9069
# Epoch 30/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9746 - auc: 0.9945 - f1_score: 0.9223 - loss: 0.2281 - precision: 0.9395 - recall: 0.9060 - val_accuracy: 0.9750 - val_auc: 0.9944 - val_f1_score: 0.9237 - val_loss: 0.2324 - val_precision: 0.9401 - val_recall: 0.9078
# Epoch 31/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9730 - auc: 0.9939 - f1_score: 0.9170 - loss: 0.2433 - precision: 0.9354 - recall: 0.9000 - val_accuracy: 0.9739 - val_auc: 0.9945 - val_f1_score: 0.9202 - val_loss: 0.2307 - val_precision: 0.9361 - val_recall: 0.9049
# Epoch 32/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 997ms/step - accuracy: 0.9751 - auc: 0.9947 - f1_score: 0.9234 - loss: 0.2305 - precision: 0.9413 - recall: 0.9074 - val_accuracy: 0.9742 - val_auc: 0.9946 - val_f1_score: 0.9210 - val_loss: 0.2281 - val_precision: 0.9362 - val_recall: 0.9069
# Epoch 33/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9756 - auc: 0.9949 - f1_score: 0.9256 - loss: 0.2230 - precision: 0.9399 - recall: 0.9122 - val_accuracy: 0.9750 - val_auc: 0.9947 - val_f1_score: 0.9236 - val_loss: 0.2251 - val_precision: 0.9401 - val_recall: 0.9078
# Epoch 34/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 995ms/step - accuracy: 0.9781 - auc: 0.9962 - f1_score: 0.9333 - loss: 0.1998 - precision: 0.9471 - recall: 0.9199 - val_accuracy: 0.9739 - val_auc: 0.9947 - val_f1_score: 0.9203 - val_loss: 0.2247 - val_precision: 0.9352 - val_recall: 0.9059
# Epoch 35/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9755 - auc: 0.9956 - f1_score: 0.9253 - loss: 0.2040 - precision: 0.9385 - recall: 0.9130 - val_accuracy: 0.9757 - val_auc: 0.9949 - val_f1_score: 0.9257 - val_loss: 0.2206 - val_precision: 0.9395 - val_recall: 0.9127
# Epoch 36/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9771 - auc: 0.9961 - f1_score: 0.9300 - loss: 0.2011 - precision: 0.9455 - recall: 0.9156 - val_accuracy: 0.9753 - val_auc: 0.9949 - val_f1_score: 0.9247 - val_loss: 0.2198 - val_precision: 0.9393 - val_recall: 0.9108
# Epoch 37/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9773 - auc: 0.9959 - f1_score: 0.9307 - loss: 0.2038 - precision: 0.9457 - recall: 0.9167 - val_accuracy: 0.9750 - val_auc: 0.9949 - val_f1_score: 0.9237 - val_loss: 0.2185 - val_precision: 0.9374 - val_recall: 0.9108
# Epoch 38/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 990ms/step - accuracy: 0.9772 - auc: 0.9957 - f1_score: 0.9305 - loss: 0.2034 - precision: 0.9442 - recall: 0.9174 - val_accuracy: 0.9743 - val_auc: 0.9949 - val_f1_score: 0.9211 - val_loss: 0.2179 - val_precision: 0.9363 - val_recall: 0.9078
# Epoch 39/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 993ms/step - accuracy: 0.9777 - auc: 0.9961 - f1_score: 0.9320 - loss: 0.1953 - precision: 0.9455 - recall: 0.9194 - val_accuracy: 0.9743 - val_auc: 0.9950 - val_f1_score: 0.9214 - val_loss: 0.2159 - val_precision: 0.9354 - val_recall: 0.9088
# Epoch 40/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 996ms/step - accuracy: 0.9806 - auc: 0.9968 - f1_score: 0.9407 - loss: 0.1818 - precision: 0.9542 - recall: 0.9283 - val_accuracy: 0.9743 - val_auc: 0.9950 - val_f1_score: 0.9220 - val_loss: 0.2149 - val_precision: 0.9354 - val_recall: 0.9088
# Epoch 41/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 994ms/step - accuracy: 0.9800 - auc: 0.9965 - f1_score: 0.9390 - loss: 0.1786 - precision: 0.9504 - recall: 0.9285 - val_accuracy: 0.9755 - val_auc: 0.9952 - val_f1_score: 0.9250 - val_loss: 0.2111 - val_precision: 0.9394 - val_recall: 0.9118
# Epoch 42/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9795 - auc: 0.9965 - f1_score: 0.9375 - loss: 0.1832 - precision: 0.9500 - recall: 0.9260 - val_accuracy: 0.9753 - val_auc: 0.9952 - val_f1_score: 0.9248 - val_loss: 0.2107 - val_precision: 0.9384 - val_recall: 0.9118
# Epoch 43/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 992ms/step - accuracy: 0.9806 - auc: 0.9968 - f1_score: 0.9408 - loss: 0.1790 - precision: 0.9532 - recall: 0.9289 - val_accuracy: 0.9763 - val_auc: 0.9953 - val_f1_score: 0.9280 - val_loss: 0.2089 - val_precision: 0.9406 - val_recall: 0.9157
# Epoch 44/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 998ms/step - accuracy: 0.9794 - auc: 0.9960 - f1_score: 0.9368 - loss: 0.1933 - precision: 0.9491 - recall: 0.9258 - val_accuracy: 0.9763 - val_auc: 0.9953 - val_f1_score: 0.9276 - val_loss: 0.2085 - val_precision: 0.9415 - val_recall: 0.9147
# Epoch 45/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9802 - auc: 0.9967 - f1_score: 0.9397 - loss: 0.1775 - precision: 0.9491 - recall: 0.9308 - val_accuracy: 0.9752 - val_auc: 0.9953 - val_f1_score: 0.9242 - val_loss: 0.2074 - val_precision: 0.9366 - val_recall: 0.9127
# Epoch 46/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9783 - auc: 0.9962 - f1_score: 0.9339 - loss: 0.1870 - precision: 0.9449 - recall: 0.9236 - val_accuracy: 0.9758 - val_auc: 0.9954 - val_f1_score: 0.9260 - val_loss: 0.2054 - val_precision: 0.9386 - val_recall: 0.9147
# Epoch 47/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9806 - auc: 0.9962 - f1_score: 0.9409 - loss: 0.1778 - precision: 0.9515 - recall: 0.9309 - val_accuracy: 0.9758 - val_auc: 0.9953 - val_f1_score: 0.9263 - val_loss: 0.2066 - val_precision: 0.9369 - val_recall: 0.9167
# Epoch 48/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9808 - auc: 0.9971 - f1_score: 0.9417 - loss: 0.1695 - precision: 0.9504 - recall: 0.9335 - val_accuracy: 0.9758 - val_auc: 0.9955 - val_f1_score: 0.9265 - val_loss: 0.2033 - val_precision: 0.9378 - val_recall: 0.9157
# Epoch 49/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9802 - auc: 0.9964 - f1_score: 0.9396 - loss: 0.1774 - precision: 0.9520 - recall: 0.9278 - val_accuracy: 0.9765 - val_auc: 0.9955 - val_f1_score: 0.9286 - val_loss: 0.2010 - val_precision: 0.9398 - val_recall: 0.9176
# Epoch 50/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 998ms/step - accuracy: 0.9802 - auc: 0.9969 - f1_score: 0.9398 - loss: 0.1710 - precision: 0.9497 - recall: 0.9303 - val_accuracy: 0.9761 - val_auc: 0.9956 - val_f1_score: 0.9273 - val_loss: 0.1996 - val_precision: 0.9396 - val_recall: 0.9157
# Epoch 51/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 999ms/step - accuracy: 0.9810 - auc: 0.9969 - f1_score: 0.9422 - loss: 0.1691 - precision: 0.9523 - recall: 0.9325 - val_accuracy: 0.9765 - val_auc: 0.9956 - val_f1_score: 0.9284 - val_loss: 0.1994 - val_precision: 0.9398 - val_recall: 0.9176
# Epoch 52/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9828 - auc: 0.9974 - f1_score: 0.9477 - loss: 0.1606 - precision: 0.9582 - recall: 0.9376 - val_accuracy: 0.9758 - val_auc: 0.9956 - val_f1_score: 0.9264 - val_loss: 0.2000 - val_precision: 0.9360 - val_recall: 0.9176
# Epoch 53/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9821 - auc: 0.9972 - f1_score: 0.9457 - loss: 0.1638 - precision: 0.9556 - recall: 0.9362 - val_accuracy: 0.9761 - val_auc: 0.9956 - val_f1_score: 0.9273 - val_loss: 0.1986 - val_precision: 0.9379 - val_recall: 0.9176
# Epoch 54/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9825 - auc: 0.9970 - f1_score: 0.9468 - loss: 0.1622 - precision: 0.9537 - recall: 0.9408 - val_accuracy: 0.9760 - val_auc: 0.9956 - val_f1_score: 0.9272 - val_loss: 0.1983 - val_precision: 0.9369 - val_recall: 0.9176
# Epoch 55/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9825 - auc: 0.9969 - f1_score: 0.9466 - loss: 0.1680 - precision: 0.9584 - recall: 0.9353 - val_accuracy: 0.9763 - val_auc: 0.9957 - val_f1_score: 0.9273 - val_loss: 0.1963 - val_precision: 0.9388 - val_recall: 0.9176
# Epoch 56/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9830 - auc: 0.9975 - f1_score: 0.9483 - loss: 0.1515 - precision: 0.9562 - recall: 0.9409 - val_accuracy: 0.9760 - val_auc: 0.9957 - val_f1_score: 0.9272 - val_loss: 0.1961 - val_precision: 0.9369 - val_recall: 0.9176
# Epoch 57/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9819 - auc: 0.9973 - f1_score: 0.9453 - loss: 0.1580 - precision: 0.9551 - recall: 0.9356 - val_accuracy: 0.9761 - val_auc: 0.9957 - val_f1_score: 0.9277 - val_loss: 0.1956 - val_precision: 0.9388 - val_recall: 0.9167
# Epoch 58/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9825 - auc: 0.9973 - f1_score: 0.9468 - loss: 0.1565 - precision: 0.9561 - recall: 0.9380 - val_accuracy: 0.9760 - val_auc: 0.9957 - val_f1_score: 0.9273 - val_loss: 0.1945 - val_precision: 0.9378 - val_recall: 0.9167
# Epoch 59/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 994ms/step - accuracy: 0.9834 - auc: 0.9975 - f1_score: 0.9495 - loss: 0.1548 - precision: 0.9595 - recall: 0.9402 - val_accuracy: 0.9760 - val_auc: 0.9958 - val_f1_score: 0.9272 - val_loss: 0.1946 - val_precision: 0.9378 - val_recall: 0.9167
# Epoch 60/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 993ms/step - accuracy: 0.9838 - auc: 0.9975 - f1_score: 0.9510 - loss: 0.1503 - precision: 0.9596 - recall: 0.9426 - val_accuracy: 0.9763 - val_auc: 0.9958 - val_f1_score: 0.9280 - val_loss: 0.1927 - val_precision: 0.9388 - val_recall: 0.9176
# Epoch 61/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 148s 984ms/step - accuracy: 0.9826 - auc: 0.9975 - f1_score: 0.9471 - loss: 0.1531 - precision: 0.9563 - recall: 0.9382 - val_accuracy: 0.9763 - val_auc: 0.9958 - val_f1_score: 0.9278 - val_loss: 0.1936 - val_precision: 0.9388 - val_recall: 0.9176
# Epoch 62/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 148s 983ms/step - accuracy: 0.9857 - auc: 0.9979 - f1_score: 0.9566 - loss: 0.1421 - precision: 0.9653 - recall: 0.9485 - val_accuracy: 0.9761 - val_auc: 0.9958 - val_f1_score: 0.9270 - val_loss: 0.1929 - val_precision: 0.9388 - val_recall: 0.9167
# Epoch 63/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9858 - auc: 0.9980 - f1_score: 0.9569 - loss: 0.1381 - precision: 0.9636 - recall: 0.9504 - val_accuracy: 0.9763 - val_auc: 0.9959 - val_f1_score: 0.9281 - val_loss: 0.1904 - val_precision: 0.9379 - val_recall: 0.9186
# Epoch 64/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9833 - auc: 0.9977 - f1_score: 0.9496 - loss: 0.1454 - precision: 0.9571 - recall: 0.9421 - val_accuracy: 0.9766 - val_auc: 0.9958 - val_f1_score: 0.9292 - val_loss: 0.1912 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 65/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9859 - auc: 0.9981 - f1_score: 0.9568 - loss: 0.1352 - precision: 0.9635 - recall: 0.9514 - val_accuracy: 0.9766 - val_auc: 0.9959 - val_f1_score: 0.9292 - val_loss: 0.1893 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 66/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9846 - auc: 0.9977 - f1_score: 0.9532 - loss: 0.1432 - precision: 0.9607 - recall: 0.9461 - val_accuracy: 0.9768 - val_auc: 0.9959 - val_f1_score: 0.9294 - val_loss: 0.1889 - val_precision: 0.9399 - val_recall: 0.9196
# Epoch 67/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 995ms/step - accuracy: 0.9861 - auc: 0.9978 - f1_score: 0.9578 - loss: 0.1433 - precision: 0.9658 - recall: 0.9502 - val_accuracy: 0.9766 - val_auc: 0.9960 - val_f1_score: 0.9293 - val_loss: 0.1875 - val_precision: 0.9381 - val_recall: 0.9206
# Epoch 68/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9860 - auc: 0.9982 - f1_score: 0.9574 - loss: 0.1336 - precision: 0.9650 - recall: 0.9502 - val_accuracy: 0.9766 - val_auc: 0.9960 - val_f1_score: 0.9289 - val_loss: 0.1881 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 69/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9853 - auc: 0.9979 - f1_score: 0.9556 - loss: 0.1412 - precision: 0.9621 - recall: 0.9494 - val_accuracy: 0.9771 - val_auc: 0.9960 - val_f1_score: 0.9308 - val_loss: 0.1866 - val_precision: 0.9400 - val_recall: 0.9216
# Epoch 70/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 993ms/step - accuracy: 0.9839 - auc: 0.9975 - f1_score: 0.9511 - loss: 0.1477 - precision: 0.9588 - recall: 0.9439 - val_accuracy: 0.9773 - val_auc: 0.9960 - val_f1_score: 0.9314 - val_loss: 0.1861 - val_precision: 0.9401 - val_recall: 0.9225
# Epoch 71/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9857 - auc: 0.9980 - f1_score: 0.9566 - loss: 0.1392 - precision: 0.9659 - recall: 0.9478 - val_accuracy: 0.9768 - val_auc: 0.9960 - val_f1_score: 0.9296 - val_loss: 0.1869 - val_precision: 0.9399 - val_recall: 0.9196
# Epoch 72/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9859 - auc: 0.9980 - f1_score: 0.9572 - loss: 0.1360 - precision: 0.9645 - recall: 0.9501 - val_accuracy: 0.9776 - val_auc: 0.9961 - val_f1_score: 0.9321 - val_loss: 0.1851 - val_precision: 0.9411 - val_recall: 0.9235
# Epoch 73/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9823 - auc: 0.9978 - f1_score: 0.9463 - loss: 0.1469 - precision: 0.9536 - recall: 0.9393 - val_accuracy: 0.9778 - val_auc: 0.9961 - val_f1_score: 0.9325 - val_loss: 0.1846 - val_precision: 0.9420 - val_recall: 0.9235
# Epoch 74/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9830 - auc: 0.9981 - f1_score: 0.9485 - loss: 0.1394 - precision: 0.9572 - recall: 0.9402 - val_accuracy: 0.9778 - val_auc: 0.9961 - val_f1_score: 0.9324 - val_loss: 0.1841 - val_precision: 0.9429 - val_recall: 0.9225
# Epoch 75/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9857 - auc: 0.9984 - f1_score: 0.9568 - loss: 0.1287 - precision: 0.9617 - recall: 0.9519 - val_accuracy: 0.9776 - val_auc: 0.9961 - val_f1_score: 0.9319 - val_loss: 0.1845 - val_precision: 0.9419 - val_recall: 0.9225
# Epoch 76/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9858 - auc: 0.9978 - f1_score: 0.9574 - loss: 0.1344 - precision: 0.9621 - recall: 0.9526 - val_accuracy: 0.9786 - val_auc: 0.9962 - val_f1_score: 0.9349 - val_loss: 0.1831 - val_precision: 0.9449 - val_recall: 0.9255
# Epoch 77/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9857 - auc: 0.9984 - f1_score: 0.9567 - loss: 0.1278 - precision: 0.9637 - recall: 0.9498 - val_accuracy: 0.9784 - val_auc: 0.9962 - val_f1_score: 0.9342 - val_loss: 0.1818 - val_precision: 0.9440 - val_recall: 0.9255
# Epoch 78/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9860 - auc: 0.9982 - f1_score: 0.9578 - loss: 0.1301 - precision: 0.9635 - recall: 0.9522 - val_accuracy: 0.9783 - val_auc: 0.9963 - val_f1_score: 0.9335 - val_loss: 0.1804 - val_precision: 0.9431 - val_recall: 0.9255
# Epoch 79/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9853 - auc: 0.9982 - f1_score: 0.9556 - loss: 0.1268 - precision: 0.9622 - recall: 0.9493 - val_accuracy: 0.9786 - val_auc: 0.9962 - val_f1_score: 0.9349 - val_loss: 0.1805 - val_precision: 0.9449 - val_recall: 0.9255
# Epoch 80/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9868 - auc: 0.9980 - f1_score: 0.9600 - loss: 0.1314 - precision: 0.9672 - recall: 0.9531 - val_accuracy: 0.9789 - val_auc: 0.9962 - val_f1_score: 0.9360 - val_loss: 0.1810 - val_precision: 0.9459 - val_recall: 0.9265
# Epoch 81/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9869 - auc: 0.9984 - f1_score: 0.9604 - loss: 0.1234 - precision: 0.9658 - recall: 0.9551 - val_accuracy: 0.9792 - val_auc: 0.9963 - val_f1_score: 0.9365 - val_loss: 0.1794 - val_precision: 0.9469 - val_recall: 0.9275
# Epoch 82/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9874 - auc: 0.9973 - f1_score: 0.9619 - loss: 0.1254 - precision: 0.9672 - recall: 0.9570 - val_accuracy: 0.9791 - val_auc: 0.9963 - val_f1_score: 0.9363 - val_loss: 0.1797 - val_precision: 0.9469 - val_recall: 0.9265
# Epoch 83/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9856 - auc: 0.9982 - f1_score: 0.9563 - loss: 0.1316 - precision: 0.9627 - recall: 0.9505 - val_accuracy: 0.9789 - val_auc: 0.9963 - val_f1_score: 0.9358 - val_loss: 0.1795 - val_precision: 0.9459 - val_recall: 0.9265
# Epoch 84/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9858 - auc: 0.9985 - f1_score: 0.9570 - loss: 0.1246 - precision: 0.9629 - recall: 0.9512 - val_accuracy: 0.9796 - val_auc: 0.9963 - val_f1_score: 0.9381 - val_loss: 0.1783 - val_precision: 0.9471 - val_recall: 0.9294
# Epoch 85/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9866 - auc: 0.9980 - f1_score: 0.9595 - loss: 0.1274 - precision: 0.9657 - recall: 0.9538 - val_accuracy: 0.9783 - val_auc: 0.9962 - val_f1_score: 0.9337 - val_loss: 0.1807 - val_precision: 0.9431 - val_recall: 0.9255
# Epoch 86/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9857 - auc: 0.9975 - f1_score: 0.9567 - loss: 0.1344 - precision: 0.9611 - recall: 0.9525 - val_accuracy: 0.9794 - val_auc: 0.9963 - val_f1_score: 0.9378 - val_loss: 0.1779 - val_precision: 0.9479 - val_recall: 0.9275
# Epoch 87/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9896 - auc: 0.9988 - f1_score: 0.9686 - loss: 0.1116 - precision: 0.9744 - recall: 0.9631 - val_accuracy: 0.9792 - val_auc: 0.9963 - val_f1_score: 0.9371 - val_loss: 0.1782 - val_precision: 0.9461 - val_recall: 0.9284
# Epoch 88/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9860 - auc: 0.9980 - f1_score: 0.9576 - loss: 0.1296 - precision: 0.9631 - recall: 0.9524 - val_accuracy: 0.9797 - val_auc: 0.9964 - val_f1_score: 0.9387 - val_loss: 0.1763 - val_precision: 0.9471 - val_recall: 0.9304
# Epoch 89/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9875 - auc: 0.9987 - f1_score: 0.9622 - loss: 0.1147 - precision: 0.9684 - recall: 0.9562 - val_accuracy: 0.9794 - val_auc: 0.9964 - val_f1_score: 0.9376 - val_loss: 0.1760 - val_precision: 0.9470 - val_recall: 0.9284
# Epoch 90/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9872 - auc: 0.9985 - f1_score: 0.9608 - loss: 0.1171 - precision: 0.9675 - recall: 0.9550 - val_accuracy: 0.9794 - val_auc: 0.9964 - val_f1_score: 0.9378 - val_loss: 0.1760 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 91/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9859 - auc: 0.9979 - f1_score: 0.9572 - loss: 0.1276 - precision: 0.9637 - recall: 0.9511 - val_accuracy: 0.9801 - val_auc: 0.9964 - val_f1_score: 0.9399 - val_loss: 0.1746 - val_precision: 0.9481 - val_recall: 0.9314
# Epoch 92/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9874 - auc: 0.9986 - f1_score: 0.9619 - loss: 0.1178 - precision: 0.9674 - recall: 0.9567 - val_accuracy: 0.9794 - val_auc: 0.9964 - val_f1_score: 0.9374 - val_loss: 0.1755 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 93/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9877 - auc: 0.9985 - f1_score: 0.9630 - loss: 0.1163 - precision: 0.9681 - recall: 0.9581 - val_accuracy: 0.9794 - val_auc: 0.9964 - val_f1_score: 0.9376 - val_loss: 0.1754 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 94/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9882 - auc: 0.9985 - f1_score: 0.9642 - loss: 0.1136 - precision: 0.9695 - recall: 0.9597 - val_accuracy: 0.9789 - val_auc: 0.9964 - val_f1_score: 0.9363 - val_loss: 0.1753 - val_precision: 0.9451 - val_recall: 0.9275

# %% [markdown]
# Result

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 97.78%

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 850ms/step

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt 
def Train_Val_plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):
    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(20, 5))
    fig.suptitle("VISUALIZE THE PERFORMANCE MATRICS")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1 Score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 Score')
    ax5.legend(['training', 'validation'])
    plt.show()

# %%
Train_Val_plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        Buras       0.95      0.92      0.94       170
#      Dangkot       0.92      0.85      0.88       170
#        Gogos       0.95      0.96      0.96       170
#     Kapurung       0.96      0.96      0.96       170
#        Sokko       0.90      0.96      0.93       170
#    Sop Konro       0.92      0.94      0.93       170
#
#     accuracy                           0.93      1020
#    macro avg       0.93      0.93      0.93      1020
# weighted avg       0.93      0.93      0.93      1020

# %%
# Import required libraries
import seaborn as sns

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_images.class_indices.keys(), yticklabels=test_images.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Saving the model
model.save('Percobaan3(7)_EfficientNetB0.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Saving the model
# ----> 2 model.save('Percobaan3(7)_EfficientNetB0.h5')
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %% [markdown]
# Deteksi

# %%
import numpy as np
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.mobilenet_v2 import preprocess_input
import matplotlib.pyplot as plt

# Load the custom MobileNetV2 model
model = load_model("D:\Kuliah Semester 6\Jurnal\Materi\CNN\Codingan\Percobaan7_EfficientNetB0.h5")

# Define the class names
class_names = ['Buras', 'Dangkot', 'Gogos', 'Kapurung', 'Sokko', 'Sop Konro']

# Define the path to your image
image_path = r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test\Sokko\SOKKO_91.jpg"

# Load and preprocess the image
img = image.load_img(image_path, target_size=(224, 224))  # Sesuaikan ukuran dengan ukuran input model Anda
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make prediction
preds = model.predict(x)

# Check the shape of the predictions
print("Predictions shape:", preds.shape)

# Get the index of the highest probability prediction
pred_index = np.argmax(preds)

# Initialize the predicted class variable
predicted_class = "Predicted index is out of range"

# Check if pred_index is within the range of class_names
if pred_index < len(class_names):
    # Get the predicted class label
    predicted_class = class_names[pred_index]

# Print the predicted class label
print("Predicted class:", predicted_class)

# Display the image along with the predicted class
plt.imshow(image.load_img(image_path))
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predictions shape: (1, 6)
# Predicted class: Kapurung
