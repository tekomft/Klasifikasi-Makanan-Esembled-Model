# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report

# %%
image_dir = Path(r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset")

# %% [markdown]
# Buat File Dataframe

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

images = pd.concat([filepaths, labels], axis=1)

category_samples = []
for category in images['Label'].unique():
    category_slice = images.query("Label == @category")
    # Ambil sampel dari setiap kategori dengan maksimum 600 gambar
    category_samples.append(category_slice.sample(min(6000, len(category_slice)), random_state=1, replace=False))

image_df = pd.concat(category_samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                                Filepath      Label
# 0     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 1     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 2     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...  Sop Konro
# 3     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 4     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# ...                                                 ...        ...
# 6793  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6794  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
# 6795  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 6796  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6797  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
#
# [6798 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# Label
# Gogos        1133
# Sop Konro    1133
# Kapurung     1133
# Buras        1133
# Dangkot      1133
# Sokko        1133
# Name: count, dtype: int64

# %%
train_dir = r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\train'
val_dir =r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\val'
test_dir=r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test'

# %% [markdown]
# Buat Train Generator

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_images = train_generator.flow_from_directory(
    directory=train_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='training'
)

val_images = train_generator.flow_from_directory(
    directory=val_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='validation'
)

test_images = test_generator.flow_from_directory(
    directory=test_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 4758 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.

# %% [markdown]
# Modelling

# %%
pretrained_model = EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(6, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)


#print(model.summary())

# %% [markdown]
# Training

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
model.compile(
    optimizer='adagrad',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc'),
        f1_score,
    ]
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=300,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/300
# c:\Program Files\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.8334 - auc: 0.6333 - f1_score: 4.8746e-04 - loss: 1.7218 - precision: 0.3933 - recall: 2.5197e-04 - val_accuracy: 0.8338 - val_auc: 0.8953 - val_f1_score: 0.0076 - val_loss: 1.3892 - val_precision: 0.8000 - val_recall: 0.0039
# Epoch 2/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.8386 - auc: 0.9087 - f1_score: 0.0621 - loss: 1.3129 - precision: 0.8420 - recall: 0.0343 - val_accuracy: 0.8654 - val_auc: 0.9533 - val_f1_score: 0.3255 - val_loss: 1.0283 - val_precision: 0.9623 - val_recall: 0.2000
# Epoch 3/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 144s 953ms/step - accuracy: 0.8750 - auc: 0.9556 - f1_score: 0.3981 - loss: 0.9781 - precision: 0.9758 - recall: 0.2569 - val_accuracy: 0.9096 - val_auc: 0.9719 - val_f1_score: 0.6326 - val_loss: 0.7830 - val_precision: 0.9587 - val_recall: 0.4784
# Epoch 4/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 928ms/step - accuracy: 0.9169 - auc: 0.9716 - f1_score: 0.6737 - loss: 0.7557 - precision: 0.9550 - recall: 0.5259 - val_accuracy: 0.9377 - val_auc: 0.9800 - val_f1_score: 0.7777 - val_loss: 0.6306 - val_precision: 0.9519 - val_recall: 0.6598
# Epoch 5/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 148s 986ms/step - accuracy: 0.9403 - auc: 0.9801 - f1_score: 0.7871 - loss: 0.6134 - precision: 0.9546 - recall: 0.6736 - val_accuracy: 0.9487 - val_auc: 0.9841 - val_f1_score: 0.8245 - val_loss: 0.5344 - val_precision: 0.9446 - val_recall: 0.7353
# Epoch 6/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9515 - auc: 0.9832 - f1_score: 0.8368 - loss: 0.5279 - precision: 0.9442 - recall: 0.7539 - val_accuracy: 0.9547 - val_auc: 0.9863 - val_f1_score: 0.8500 - val_loss: 0.4717 - val_precision: 0.9355 - val_recall: 0.7824
# Epoch 7/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 995ms/step - accuracy: 0.9544 - auc: 0.9844 - f1_score: 0.8487 - loss: 0.4844 - precision: 0.9385 - recall: 0.7771 - val_accuracy: 0.9593 - val_auc: 0.9882 - val_f1_score: 0.8672 - val_loss: 0.4251 - val_precision: 0.9416 - val_recall: 0.8059
# Epoch 8/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 996ms/step - accuracy: 0.9596 - auc: 0.9872 - f1_score: 0.8691 - loss: 0.4352 - precision: 0.9375 - recall: 0.8117 - val_accuracy: 0.9611 - val_auc: 0.9893 - val_f1_score: 0.8744 - val_loss: 0.3930 - val_precision: 0.9354 - val_recall: 0.8235
# Epoch 9/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9589 - auc: 0.9883 - f1_score: 0.8680 - loss: 0.4052 - precision: 0.9265 - recall: 0.8182 - val_accuracy: 0.9637 - val_auc: 0.9903 - val_f1_score: 0.8845 - val_loss: 0.3663 - val_precision: 0.9385 - val_recall: 0.8373
# Epoch 10/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9612 - auc: 0.9894 - f1_score: 0.8768 - loss: 0.3808 - precision: 0.9281 - recall: 0.8317 - val_accuracy: 0.9655 - val_auc: 0.9909 - val_f1_score: 0.8910 - val_loss: 0.3461 - val_precision: 0.9382 - val_recall: 0.8490
# Epoch 11/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9646 - auc: 0.9909 - f1_score: 0.8878 - loss: 0.3502 - precision: 0.9346 - recall: 0.8466 - val_accuracy: 0.9670 - val_auc: 0.9916 - val_f1_score: 0.8955 - val_loss: 0.3291 - val_precision: 0.9388 - val_recall: 0.8578
# Epoch 12/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 150s 997ms/step - accuracy: 0.9649 - auc: 0.9902 - f1_score: 0.8900 - loss: 0.3469 - precision: 0.9283 - recall: 0.8558 - val_accuracy: 0.9672 - val_auc: 0.9920 - val_f1_score: 0.8956 - val_loss: 0.3157 - val_precision: 0.9398 - val_recall: 0.8578
# Epoch 13/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9700 - auc: 0.9926 - f1_score: 0.9056 - loss: 0.3115 - precision: 0.9438 - recall: 0.8717 - val_accuracy: 0.9693 - val_auc: 0.9924 - val_f1_score: 0.9038 - val_loss: 0.3040 - val_precision: 0.9416 - val_recall: 0.8696
# Epoch 14/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 151s 999ms/step - accuracy: 0.9676 - auc: 0.9923 - f1_score: 0.8981 - loss: 0.3101 - precision: 0.9379 - recall: 0.8626 - val_accuracy: 0.9698 - val_auc: 0.9928 - val_f1_score: 0.9053 - val_loss: 0.2935 - val_precision: 0.9418 - val_recall: 0.8725
# Epoch 15/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9693 - auc: 0.9928 - f1_score: 0.9040 - loss: 0.2948 - precision: 0.9363 - recall: 0.8755 - val_accuracy: 0.9706 - val_auc: 0.9931 - val_f1_score: 0.9080 - val_loss: 0.2847 - val_precision: 0.9421 - val_recall: 0.8775
# Epoch 16/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.9703 - auc: 0.9927 - f1_score: 0.9070 - loss: 0.2884 - precision: 0.9416 - recall: 0.8762 - val_accuracy: 0.9709 - val_auc: 0.9930 - val_f1_score: 0.9095 - val_loss: 0.2779 - val_precision: 0.9413 - val_recall: 0.8804
# Epoch 17/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9720 - auc: 0.9934 - f1_score: 0.9128 - loss: 0.2746 - precision: 0.9430 - recall: 0.8854 - val_accuracy: 0.9717 - val_auc: 0.9933 - val_f1_score: 0.9123 - val_loss: 0.2701 - val_precision: 0.9425 - val_recall: 0.8843
# Epoch 18/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9721 - auc: 0.9936 - f1_score: 0.9134 - loss: 0.2677 - precision: 0.9407 - recall: 0.8886 - val_accuracy: 0.9727 - val_auc: 0.9935 - val_f1_score: 0.9154 - val_loss: 0.2642 - val_precision: 0.9429 - val_recall: 0.8902
# Epoch 19/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9729 - auc: 0.9946 - f1_score: 0.9167 - loss: 0.2536 - precision: 0.9424 - recall: 0.8923 - val_accuracy: 0.9730 - val_auc: 0.9936 - val_f1_score: 0.9166 - val_loss: 0.2594 - val_precision: 0.9439 - val_recall: 0.8912
# Epoch 20/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9734 - auc: 0.9944 - f1_score: 0.9175 - loss: 0.2528 - precision: 0.9415 - recall: 0.8959 - val_accuracy: 0.9730 - val_auc: 0.9938 - val_f1_score: 0.9166 - val_loss: 0.2536 - val_precision: 0.9394 - val_recall: 0.8961
# Epoch 21/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.9757 - auc: 0.9948 - f1_score: 0.9250 - loss: 0.2418 - precision: 0.9483 - recall: 0.9034 - val_accuracy: 0.9735 - val_auc: 0.9940 - val_f1_score: 0.9182 - val_loss: 0.2492 - val_precision: 0.9405 - val_recall: 0.8980
# Epoch 22/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9757 - auc: 0.9945 - f1_score: 0.9246 - loss: 0.2450 - precision: 0.9500 - recall: 0.9014 - val_accuracy: 0.9739 - val_auc: 0.9940 - val_f1_score: 0.9198 - val_loss: 0.2458 - val_precision: 0.9406 - val_recall: 0.9000
# Epoch 23/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9727 - auc: 0.9938 - f1_score: 0.9156 - loss: 0.2489 - precision: 0.9374 - recall: 0.8958 - val_accuracy: 0.9739 - val_auc: 0.9941 - val_f1_score: 0.9195 - val_loss: 0.2424 - val_precision: 0.9397 - val_recall: 0.9010
# Epoch 24/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9748 - auc: 0.9951 - f1_score: 0.9226 - loss: 0.2305 - precision: 0.9444 - recall: 0.9021 - val_accuracy: 0.9737 - val_auc: 0.9943 - val_f1_score: 0.9188 - val_loss: 0.2387 - val_precision: 0.9414 - val_recall: 0.8980
# Epoch 25/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9768 - auc: 0.9952 - f1_score: 0.9288 - loss: 0.2253 - precision: 0.9491 - recall: 0.9095 - val_accuracy: 0.9740 - val_auc: 0.9943 - val_f1_score: 0.9205 - val_loss: 0.2359 - val_precision: 0.9388 - val_recall: 0.9029
# Epoch 26/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9760 - auc: 0.9957 - f1_score: 0.9261 - loss: 0.2202 - precision: 0.9474 - recall: 0.9064 - val_accuracy: 0.9750 - val_auc: 0.9945 - val_f1_score: 0.9234 - val_loss: 0.2316 - val_precision: 0.9419 - val_recall: 0.9059
# Epoch 27/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9771 - auc: 0.9953 - f1_score: 0.9298 - loss: 0.2182 - precision: 0.9461 - recall: 0.9145 - val_accuracy: 0.9743 - val_auc: 0.9946 - val_f1_score: 0.9211 - val_loss: 0.2300 - val_precision: 0.9390 - val_recall: 0.9049
# Epoch 28/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9758 - auc: 0.9951 - f1_score: 0.9256 - loss: 0.2157 - precision: 0.9427 - recall: 0.9100 - val_accuracy: 0.9742 - val_auc: 0.9947 - val_f1_score: 0.9206 - val_loss: 0.2272 - val_precision: 0.9380 - val_recall: 0.9049
# Epoch 29/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9793 - auc: 0.9960 - f1_score: 0.9367 - loss: 0.2094 - precision: 0.9534 - recall: 0.9210 - val_accuracy: 0.9748 - val_auc: 0.9948 - val_f1_score: 0.9231 - val_loss: 0.2244 - val_precision: 0.9383 - val_recall: 0.9088
# Epoch 30/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9793 - auc: 0.9960 - f1_score: 0.9366 - loss: 0.2041 - precision: 0.9531 - recall: 0.9209 - val_accuracy: 0.9752 - val_auc: 0.9948 - val_f1_score: 0.9245 - val_loss: 0.2223 - val_precision: 0.9384 - val_recall: 0.9108
# Epoch 31/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9805 - auc: 0.9962 - f1_score: 0.9403 - loss: 0.1977 - precision: 0.9568 - recall: 0.9246 - val_accuracy: 0.9752 - val_auc: 0.9948 - val_f1_score: 0.9244 - val_loss: 0.2213 - val_precision: 0.9393 - val_recall: 0.9098
# Epoch 32/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 146s 964ms/step - accuracy: 0.9768 - auc: 0.9953 - f1_score: 0.9286 - loss: 0.2130 - precision: 0.9465 - recall: 0.9122 - val_accuracy: 0.9761 - val_auc: 0.9950 - val_f1_score: 0.9269 - val_loss: 0.2184 - val_precision: 0.9423 - val_recall: 0.9127
# Epoch 33/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 149s 986ms/step - accuracy: 0.9799 - auc: 0.9962 - f1_score: 0.9387 - loss: 0.1957 - precision: 0.9536 - recall: 0.9246 - val_accuracy: 0.9761 - val_auc: 0.9951 - val_f1_score: 0.9275 - val_loss: 0.2155 - val_precision: 0.9414 - val_recall: 0.9137
# Epoch 34/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.9795 - auc: 0.9968 - f1_score: 0.9369 - loss: 0.1944 - precision: 0.9559 - recall: 0.9191 - val_accuracy: 0.9765 - val_auc: 0.9951 - val_f1_score: 0.9285 - val_loss: 0.2142 - val_precision: 0.9415 - val_recall: 0.9157
# Epoch 35/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.9796 - auc: 0.9968 - f1_score: 0.9374 - loss: 0.1906 - precision: 0.9553 - recall: 0.9207 - val_accuracy: 0.9765 - val_auc: 0.9951 - val_f1_score: 0.9281 - val_loss: 0.2121 - val_precision: 0.9406 - val_recall: 0.9167
# Epoch 36/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.9797 - auc: 0.9959 - f1_score: 0.9380 - loss: 0.1969 - precision: 0.9532 - recall: 0.9237 - val_accuracy: 0.9763 - val_auc: 0.9952 - val_f1_score: 0.9279 - val_loss: 0.2105 - val_precision: 0.9397 - val_recall: 0.9167
# Epoch 37/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9797 - auc: 0.9968 - f1_score: 0.9377 - loss: 0.1880 - precision: 0.9534 - recall: 0.9232 - val_accuracy: 0.9768 - val_auc: 0.9953 - val_f1_score: 0.9292 - val_loss: 0.2082 - val_precision: 0.9416 - val_recall: 0.9176
# Epoch 38/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9800 - auc: 0.9961 - f1_score: 0.9389 - loss: 0.1924 - precision: 0.9539 - recall: 0.9248 - val_accuracy: 0.9761 - val_auc: 0.9953 - val_f1_score: 0.9269 - val_loss: 0.2075 - val_precision: 0.9405 - val_recall: 0.9147
# Epoch 39/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.9813 - auc: 0.9972 - f1_score: 0.9431 - loss: 0.1737 - precision: 0.9576 - recall: 0.9293 - val_accuracy: 0.9763 - val_auc: 0.9953 - val_f1_score: 0.9276 - val_loss: 0.2061 - val_precision: 0.9397 - val_recall: 0.9167
# Epoch 40/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9807 - auc: 0.9970 - f1_score: 0.9407 - loss: 0.1821 - precision: 0.9584 - recall: 0.9242 - val_accuracy: 0.9761 - val_auc: 0.9954 - val_f1_score: 0.9274 - val_loss: 0.2042 - val_precision: 0.9388 - val_recall: 0.9167
# Epoch 41/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.9817 - auc: 0.9969 - f1_score: 0.9443 - loss: 0.1734 - precision: 0.9574 - recall: 0.9320 - val_accuracy: 0.9770 - val_auc: 0.9955 - val_f1_score: 0.9300 - val_loss: 0.2032 - val_precision: 0.9399 - val_recall: 0.9206
# Epoch 42/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9833 - auc: 0.9969 - f1_score: 0.9489 - loss: 0.1725 - precision: 0.9618 - recall: 0.9372 - val_accuracy: 0.9761 - val_auc: 0.9955 - val_f1_score: 0.9278 - val_loss: 0.2023 - val_precision: 0.9379 - val_recall: 0.9176
# Epoch 43/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9820 - auc: 0.9969 - f1_score: 0.9449 - loss: 0.1742 - precision: 0.9558 - recall: 0.9350 - val_accuracy: 0.9770 - val_auc: 0.9955 - val_f1_score: 0.9304 - val_loss: 0.2005 - val_precision: 0.9399 - val_recall: 0.9206
# Epoch 44/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9824 - auc: 0.9969 - f1_score: 0.9464 - loss: 0.1730 - precision: 0.9572 - recall: 0.9361 - val_accuracy: 0.9768 - val_auc: 0.9955 - val_f1_score: 0.9292 - val_loss: 0.1999 - val_precision: 0.9399 - val_recall: 0.9196
# Epoch 45/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9832 - auc: 0.9976 - f1_score: 0.9489 - loss: 0.1617 - precision: 0.9610 - recall: 0.9374 - val_accuracy: 0.9771 - val_auc: 0.9956 - val_f1_score: 0.9302 - val_loss: 0.1975 - val_precision: 0.9409 - val_recall: 0.9206
# Epoch 46/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9828 - auc: 0.9971 - f1_score: 0.9478 - loss: 0.1681 - precision: 0.9574 - recall: 0.9389 - val_accuracy: 0.9768 - val_auc: 0.9956 - val_f1_score: 0.9291 - val_loss: 0.1973 - val_precision: 0.9399 - val_recall: 0.9196
# Epoch 47/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9841 - auc: 0.9975 - f1_score: 0.9512 - loss: 0.1631 - precision: 0.9624 - recall: 0.9415 - val_accuracy: 0.9768 - val_auc: 0.9956 - val_f1_score: 0.9294 - val_loss: 0.1977 - val_precision: 0.9390 - val_recall: 0.9206
# Epoch 48/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.9825 - auc: 0.9974 - f1_score: 0.9467 - loss: 0.1625 - precision: 0.9577 - recall: 0.9361 - val_accuracy: 0.9776 - val_auc: 0.9957 - val_f1_score: 0.9322 - val_loss: 0.1949 - val_precision: 0.9419 - val_recall: 0.9225
# Epoch 49/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9826 - auc: 0.9970 - f1_score: 0.9473 - loss: 0.1682 - precision: 0.9569 - recall: 0.9381 - val_accuracy: 0.9776 - val_auc: 0.9957 - val_f1_score: 0.9323 - val_loss: 0.1941 - val_precision: 0.9419 - val_recall: 0.9225
# Epoch 50/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9828 - auc: 0.9978 - f1_score: 0.9478 - loss: 0.1541 - precision: 0.9578 - recall: 0.9381 - val_accuracy: 0.9783 - val_auc: 0.9958 - val_f1_score: 0.9339 - val_loss: 0.1927 - val_precision: 0.9439 - val_recall: 0.9245
# Epoch 51/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9834 - auc: 0.9969 - f1_score: 0.9495 - loss: 0.1615 - precision: 0.9603 - recall: 0.9390 - val_accuracy: 0.9784 - val_auc: 0.9958 - val_f1_score: 0.9348 - val_loss: 0.1929 - val_precision: 0.9422 - val_recall: 0.9275
# Epoch 52/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9829 - auc: 0.9971 - f1_score: 0.9481 - loss: 0.1666 - precision: 0.9599 - recall: 0.9368 - val_accuracy: 0.9781 - val_auc: 0.9958 - val_f1_score: 0.9332 - val_loss: 0.1923 - val_precision: 0.9421 - val_recall: 0.9255
# Epoch 53/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9827 - auc: 0.9969 - f1_score: 0.9475 - loss: 0.1669 - precision: 0.9585 - recall: 0.9368 - val_accuracy: 0.9779 - val_auc: 0.9958 - val_f1_score: 0.9330 - val_loss: 0.1906 - val_precision: 0.9421 - val_recall: 0.9245
# Epoch 54/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9834 - auc: 0.9976 - f1_score: 0.9494 - loss: 0.1568 - precision: 0.9630 - recall: 0.9362 - val_accuracy: 0.9783 - val_auc: 0.9959 - val_f1_score: 0.9343 - val_loss: 0.1896 - val_precision: 0.9431 - val_recall: 0.9255
# Epoch 55/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9847 - auc: 0.9978 - f1_score: 0.9537 - loss: 0.1496 - precision: 0.9616 - recall: 0.9460 - val_accuracy: 0.9786 - val_auc: 0.9959 - val_f1_score: 0.9345 - val_loss: 0.1885 - val_precision: 0.9441 - val_recall: 0.9265
# Epoch 56/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9859 - auc: 0.9981 - f1_score: 0.9573 - loss: 0.1453 - precision: 0.9662 - recall: 0.9489 - val_accuracy: 0.9786 - val_auc: 0.9959 - val_f1_score: 0.9349 - val_loss: 0.1878 - val_precision: 0.9449 - val_recall: 0.9255
# Epoch 57/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9844 - auc: 0.9981 - f1_score: 0.9525 - loss: 0.1441 - precision: 0.9630 - recall: 0.9428 - val_accuracy: 0.9783 - val_auc: 0.9959 - val_f1_score: 0.9343 - val_loss: 0.1884 - val_precision: 0.9422 - val_recall: 0.9265
# Epoch 58/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9848 - auc: 0.9980 - f1_score: 0.9537 - loss: 0.1474 - precision: 0.9627 - recall: 0.9451 - val_accuracy: 0.9788 - val_auc: 0.9960 - val_f1_score: 0.9357 - val_loss: 0.1864 - val_precision: 0.9450 - val_recall: 0.9265
# Epoch 59/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9849 - auc: 0.9978 - f1_score: 0.9540 - loss: 0.1497 - precision: 0.9638 - recall: 0.9448 - val_accuracy: 0.9788 - val_auc: 0.9960 - val_f1_score: 0.9357 - val_loss: 0.1855 - val_precision: 0.9450 - val_recall: 0.9265
# Epoch 60/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9848 - auc: 0.9979 - f1_score: 0.9539 - loss: 0.1466 - precision: 0.9648 - recall: 0.9434 - val_accuracy: 0.9792 - val_auc: 0.9960 - val_f1_score: 0.9372 - val_loss: 0.1845 - val_precision: 0.9461 - val_recall: 0.9284
# Epoch 61/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9865 - auc: 0.9976 - f1_score: 0.9589 - loss: 0.1428 - precision: 0.9680 - recall: 0.9501 - val_accuracy: 0.9792 - val_auc: 0.9960 - val_f1_score: 0.9370 - val_loss: 0.1843 - val_precision: 0.9461 - val_recall: 0.9284
# Epoch 62/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9877 - auc: 0.9985 - f1_score: 0.9628 - loss: 0.1292 - precision: 0.9696 - recall: 0.9563 - val_accuracy: 0.9796 - val_auc: 0.9960 - val_f1_score: 0.9375 - val_loss: 0.1845 - val_precision: 0.9471 - val_recall: 0.9294
# Epoch 63/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9860 - auc: 0.9980 - f1_score: 0.9574 - loss: 0.1432 - precision: 0.9646 - recall: 0.9509 - val_accuracy: 0.9799 - val_auc: 0.9960 - val_f1_score: 0.9392 - val_loss: 0.1841 - val_precision: 0.9472 - val_recall: 0.9314
# Epoch 64/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9876 - auc: 0.9983 - f1_score: 0.9626 - loss: 0.1295 - precision: 0.9689 - recall: 0.9565 - val_accuracy: 0.9794 - val_auc: 0.9961 - val_f1_score: 0.9379 - val_loss: 0.1839 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 65/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9860 - auc: 0.9978 - f1_score: 0.9576 - loss: 0.1408 - precision: 0.9660 - recall: 0.9496 - val_accuracy: 0.9796 - val_auc: 0.9961 - val_f1_score: 0.9383 - val_loss: 0.1820 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 66/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9859 - auc: 0.9981 - f1_score: 0.9575 - loss: 0.1379 - precision: 0.9642 - recall: 0.9510 - val_accuracy: 0.9794 - val_auc: 0.9961 - val_f1_score: 0.9375 - val_loss: 0.1826 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 67/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9846 - auc: 0.9983 - f1_score: 0.9533 - loss: 0.1389 - precision: 0.9605 - recall: 0.9465 - val_accuracy: 0.9801 - val_auc: 0.9962 - val_f1_score: 0.9396 - val_loss: 0.1810 - val_precision: 0.9481 - val_recall: 0.9314
# Epoch 68/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9863 - auc: 0.9984 - f1_score: 0.9583 - loss: 0.1319 - precision: 0.9669 - recall: 0.9501 - val_accuracy: 0.9797 - val_auc: 0.9961 - val_f1_score: 0.9384 - val_loss: 0.1813 - val_precision: 0.9471 - val_recall: 0.9304
# Epoch 69/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9844 - auc: 0.9983 - f1_score: 0.9528 - loss: 0.1373 - precision: 0.9618 - recall: 0.9442 - val_accuracy: 0.9806 - val_auc: 0.9962 - val_f1_score: 0.9411 - val_loss: 0.1800 - val_precision: 0.9500 - val_recall: 0.9324
# Epoch 70/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9858 - auc: 0.9981 - f1_score: 0.9570 - loss: 0.1395 - precision: 0.9639 - recall: 0.9505 - val_accuracy: 0.9810 - val_auc: 0.9962 - val_f1_score: 0.9428 - val_loss: 0.1796 - val_precision: 0.9493 - val_recall: 0.9363
# Epoch 71/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9885 - auc: 0.9986 - f1_score: 0.9652 - loss: 0.1222 - precision: 0.9709 - recall: 0.9597 - val_accuracy: 0.9806 - val_auc: 0.9962 - val_f1_score: 0.9407 - val_loss: 0.1785 - val_precision: 0.9492 - val_recall: 0.9333
# Epoch 72/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9875 - auc: 0.9986 - f1_score: 0.9619 - loss: 0.1253 - precision: 0.9689 - recall: 0.9555 - val_accuracy: 0.9806 - val_auc: 0.9962 - val_f1_score: 0.9410 - val_loss: 0.1793 - val_precision: 0.9492 - val_recall: 0.9333
# Epoch 73/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9863 - auc: 0.9979 - f1_score: 0.9586 - loss: 0.1363 - precision: 0.9656 - recall: 0.9519 - val_accuracy: 0.9809 - val_auc: 0.9962 - val_f1_score: 0.9420 - val_loss: 0.1778 - val_precision: 0.9493 - val_recall: 0.9353
# Epoch 74/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9877 - auc: 0.9984 - f1_score: 0.9629 - loss: 0.1222 - precision: 0.9694 - recall: 0.9567 - val_accuracy: 0.9802 - val_auc: 0.9962 - val_f1_score: 0.9403 - val_loss: 0.1780 - val_precision: 0.9473 - val_recall: 0.9333
# Epoch 75/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9857 - auc: 0.9981 - f1_score: 0.9569 - loss: 0.1341 - precision: 0.9621 - recall: 0.9519 - val_accuracy: 0.9812 - val_auc: 0.9963 - val_f1_score: 0.9431 - val_loss: 0.1768 - val_precision: 0.9502 - val_recall: 0.9363
# Epoch 76/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9885 - auc: 0.9988 - f1_score: 0.9652 - loss: 0.1170 - precision: 0.9743 - recall: 0.9565 - val_accuracy: 0.9810 - val_auc: 0.9963 - val_f1_score: 0.9424 - val_loss: 0.1763 - val_precision: 0.9493 - val_recall: 0.9363
# Epoch 77/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9875 - auc: 0.9985 - f1_score: 0.9624 - loss: 0.1248 - precision: 0.9687 - recall: 0.9558 - val_accuracy: 0.9810 - val_auc: 0.9963 - val_f1_score: 0.9425 - val_loss: 0.1760 - val_precision: 0.9493 - val_recall: 0.9363
# Epoch 78/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.9865 - auc: 0.9984 - f1_score: 0.9592 - loss: 0.1264 - precision: 0.9654 - recall: 0.9531 - val_accuracy: 0.9810 - val_auc: 0.9963 - val_f1_score: 0.9421 - val_loss: 0.1760 - val_precision: 0.9493 - val_recall: 0.9363
# Epoch 79/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.9863 - auc: 0.9975 - f1_score: 0.9585 - loss: 0.1320 - precision: 0.9656 - recall: 0.9515 - val_accuracy: 0.9812 - val_auc: 0.9963 - val_f1_score: 0.9432 - val_loss: 0.1751 - val_precision: 0.9494 - val_recall: 0.9373
# Epoch 80/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.9869 - auc: 0.9986 - f1_score: 0.9601 - loss: 0.1215 - precision: 0.9690 - recall: 0.9518 - val_accuracy: 0.9810 - val_auc: 0.9964 - val_f1_score: 0.9427 - val_loss: 0.1747 - val_precision: 0.9502 - val_recall: 0.9353
# Epoch 81/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9863 - auc: 0.9984 - f1_score: 0.9587 - loss: 0.1287 - precision: 0.9644 - recall: 0.9529 - val_accuracy: 0.9815 - val_auc: 0.9964 - val_f1_score: 0.9440 - val_loss: 0.1743 - val_precision: 0.9512 - val_recall: 0.9373
# Epoch 82/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9886 - auc: 0.9987 - f1_score: 0.9654 - loss: 0.1161 - precision: 0.9711 - recall: 0.9603 - val_accuracy: 0.9809 - val_auc: 0.9964 - val_f1_score: 0.9423 - val_loss: 0.1742 - val_precision: 0.9484 - val_recall: 0.9363
# Epoch 83/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9882 - auc: 0.9986 - f1_score: 0.9641 - loss: 0.1213 - precision: 0.9708 - recall: 0.9579 - val_accuracy: 0.9809 - val_auc: 0.9963 - val_f1_score: 0.9420 - val_loss: 0.1744 - val_precision: 0.9484 - val_recall: 0.9363
# Epoch 84/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.9877 - auc: 0.9986 - f1_score: 0.9628 - loss: 0.1183 - precision: 0.9692 - recall: 0.9567 - val_accuracy: 0.9810 - val_auc: 0.9964 - val_f1_score: 0.9428 - val_loss: 0.1740 - val_precision: 0.9484 - val_recall: 0.9373
# Epoch 85/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9873 - auc: 0.9988 - f1_score: 0.9615 - loss: 0.1161 - precision: 0.9669 - recall: 0.9564 - val_accuracy: 0.9810 - val_auc: 0.9964 - val_f1_score: 0.9428 - val_loss: 0.1738 - val_precision: 0.9484 - val_recall: 0.9373
# Epoch 86/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9871 - auc: 0.9985 - f1_score: 0.9612 - loss: 0.1223 - precision: 0.9664 - recall: 0.9561 - val_accuracy: 0.9812 - val_auc: 0.9964 - val_f1_score: 0.9433 - val_loss: 0.1726 - val_precision: 0.9502 - val_recall: 0.9363
# Epoch 87/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9871 - auc: 0.9985 - f1_score: 0.9609 - loss: 0.1210 - precision: 0.9682 - recall: 0.9540 - val_accuracy: 0.9814 - val_auc: 0.9965 - val_f1_score: 0.9433 - val_loss: 0.1717 - val_precision: 0.9521 - val_recall: 0.9353
# Epoch 88/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9896 - auc: 0.9987 - f1_score: 0.9687 - loss: 0.1096 - precision: 0.9754 - recall: 0.9619 - val_accuracy: 0.9814 - val_auc: 0.9964 - val_f1_score: 0.9439 - val_loss: 0.1725 - val_precision: 0.9503 - val_recall: 0.9373
# Epoch 89/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9898 - auc: 0.9990 - f1_score: 0.9690 - loss: 0.1100 - precision: 0.9738 - recall: 0.9645 - val_accuracy: 0.9812 - val_auc: 0.9964 - val_f1_score: 0.9430 - val_loss: 0.1728 - val_precision: 0.9494 - val_recall: 0.9373
# Epoch 90/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9893 - auc: 0.9989 - f1_score: 0.9677 - loss: 0.1092 - precision: 0.9728 - recall: 0.9629 - val_accuracy: 0.9814 - val_auc: 0.9964 - val_f1_score: 0.9438 - val_loss: 0.1719 - val_precision: 0.9503 - val_recall: 0.9373

# %% [markdown]
# Result

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 97.73%

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 835ms/step

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt 
def Train_Val_plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):
    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(20, 5))
    fig.suptitle("VISUALIZE THE PERFORMANCE MATRICS")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1 Score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 Score')
    ax5.legend(['training', 'validation'])
    plt.show()

# %%
Train_Val_plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        Buras       0.94      0.94      0.94       170
#      Dangkot       0.92      0.86      0.89       170
#        Gogos       0.96      0.95      0.96       170
#     Kapurung       0.95      0.95      0.95       170
#        Sokko       0.91      0.95      0.93       170
#    Sop Konro       0.91      0.94      0.93       170
#
#     accuracy                           0.93      1020
#    macro avg       0.93      0.93      0.93      1020
# weighted avg       0.93      0.93      0.93      1020

# %%
# Import required libraries
import seaborn as sns

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_images.class_indices.keys(), yticklabels=test_images.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Saving the model
model.save('Percobaan3(5)_EfficientNetB0.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Saving the model
# ----> 2 model.save('Percobaan3(5)_EfficientNetB0.h5')
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %% [markdown]
# Deteksi

# %%
import numpy as np
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.mobilenet_v2 import preprocess_input
import matplotlib.pyplot as plt

# Load the custom MobileNetV2 model
model = load_model("D:\Kuliah Semester 6\Jurnal\Materi\CNN\Codingan\Percobaan3(5)_EfficientNetB0.h5")

# Define the class names
class_names = ['Buras', 'Dangkot', 'Gogos', 'Kapurung', 'Sokko', 'Sop Konro']

# Define the path to your image
image_path = r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test\Sokko\SOKKO_91.jpg"

# Load and preprocess the image
img = image.load_img(image_path, target_size=(224, 224))  # Sesuaikan ukuran dengan ukuran input model Anda
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make prediction
preds = model.predict(x)

# Check the shape of the predictions
print("Predictions shape:", preds.shape)

# Get the index of the highest probability prediction
pred_index = np.argmax(preds)

# Initialize the predicted class variable
predicted_class = "Predicted index is out of range"

# Check if pred_index is within the range of class_names
if pred_index < len(class_names):
    # Get the predicted class label
    predicted_class = class_names[pred_index]

# Print the predicted class label
print("Predicted class:", predicted_class)

# Display the image along with the predicted class
plt.imshow(image.load_img(image_path))
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predictions shape: (1, 6)
# Predicted class: Kapurung
