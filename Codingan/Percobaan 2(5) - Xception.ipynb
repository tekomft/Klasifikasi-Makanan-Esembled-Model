# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# %%
image_dir = Path(r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset")

# %% [markdown]
# Buat File Dataframe

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

images = pd.concat([filepaths, labels], axis=1)

category_samples = []
for category in images['Label'].unique():
    category_slice = images.query("Label == @category")
    # Ambil sampel dari setiap kategori dengan maksimum 600 gambar
    category_samples.append(category_slice.sample(min(6000, len(category_slice)), random_state=1, replace=False))

image_df = pd.concat(category_samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                                Filepath      Label
# 0     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 1     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 2     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...  Sop Konro
# 3     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 4     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# ...                                                 ...        ...
# 6793  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6794  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
# 6795  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 6796  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6797  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
#
# [6798 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# Label
# Gogos        1133
# Sop Konro    1133
# Kapurung     1133
# Buras        1133
# Dangkot      1133
# Sokko        1133
# Name: count, dtype: int64

# %%
train_dir = r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\train'
val_dir =r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\val'
test_dir=r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test'

# %% [markdown]
# Buat Train Generator

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.xception.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.xception.preprocess_input
)

# %%
train_images = train_generator.flow_from_directory(
    directory=train_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='training'
)

val_images = train_generator.flow_from_directory(
    directory=val_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
    #subset='validation'
)

test_images = test_generator.flow_from_directory(
    directory=test_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 4758 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.

# %% [markdown]
# Modelling

# %%
pretrained_model = tf.keras.applications.Xception(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False
#print(pretrained_model.summary())

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(6, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)


#print(model.summary())

# %% [markdown]
# Training

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
model.compile(
    optimizer='adagrad',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc'),
        f1_score,
    ]
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=300,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/300
# c:\Program Files\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 556s 4s/step - accuracy: 0.8334 - auc: 0.6340 - f1_score: 9.3451e-04 - loss: 1.7179 - precision: 0.2533 - recall: 4.6909e-04 - val_accuracy: 0.8369 - val_auc: 0.8972 - val_f1_score: 0.0415 - val_loss: 1.3878 - val_precision: 1.0000 - val_recall: 0.0216
# Epoch 2/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 537s 4s/step - accuracy: 0.8427 - auc: 0.9206 - f1_score: 0.1033 - loss: 1.2733 - precision: 0.9732 - recall: 0.0574 - val_accuracy: 0.8711 - val_auc: 0.9496 - val_f1_score: 0.3713 - val_loss: 1.0141 - val_precision: 0.9714 - val_recall: 0.2333
# Epoch 3/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 520s 3s/step - accuracy: 0.8881 - auc: 0.9538 - f1_score: 0.4970 - loss: 0.9384 - precision: 0.9636 - recall: 0.3418 - val_accuracy: 0.9152 - val_auc: 0.9684 - val_f1_score: 0.6648 - val_loss: 0.7798 - val_precision: 0.9580 - val_recall: 0.5137
# Epoch 4/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 518s 3s/step - accuracy: 0.9190 - auc: 0.9677 - f1_score: 0.6909 - loss: 0.7438 - precision: 0.9320 - recall: 0.5542 - val_accuracy: 0.9327 - val_auc: 0.9764 - val_f1_score: 0.7576 - val_loss: 0.6476 - val_precision: 0.9406 - val_recall: 0.6363
# Epoch 5/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 519s 3s/step - accuracy: 0.9370 - auc: 0.9748 - f1_score: 0.7793 - loss: 0.6273 - precision: 0.9259 - recall: 0.6760 - val_accuracy: 0.9435 - val_auc: 0.9808 - val_f1_score: 0.8055 - val_loss: 0.5653 - val_precision: 0.9354 - val_recall: 0.7098
# Epoch 6/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 518s 3s/step - accuracy: 0.9438 - auc: 0.9797 - f1_score: 0.8102 - loss: 0.5458 - precision: 0.9207 - recall: 0.7255 - val_accuracy: 0.9489 - val_auc: 0.9836 - val_f1_score: 0.8276 - val_loss: 0.5081 - val_precision: 0.9327 - val_recall: 0.7471
# Epoch 7/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 517s 3s/step - accuracy: 0.9477 - auc: 0.9798 - f1_score: 0.8265 - loss: 0.5158 - precision: 0.9160 - recall: 0.7552 - val_accuracy: 0.9526 - val_auc: 0.9852 - val_f1_score: 0.8429 - val_loss: 0.4687 - val_precision: 0.9294 - val_recall: 0.7745
# Epoch 8/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 520s 3s/step - accuracy: 0.9526 - auc: 0.9837 - f1_score: 0.8459 - loss: 0.4676 - precision: 0.9208 - recall: 0.7832 - val_accuracy: 0.9554 - val_auc: 0.9864 - val_f1_score: 0.8543 - val_loss: 0.4394 - val_precision: 0.9328 - val_recall: 0.7892
# Epoch 9/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 521s 3s/step - accuracy: 0.9590 - auc: 0.9873 - f1_score: 0.8679 - loss: 0.4139 - precision: 0.9303 - recall: 0.8153 - val_accuracy: 0.9578 - val_auc: 0.9874 - val_f1_score: 0.8630 - val_loss: 0.4168 - val_precision: 0.9339 - val_recall: 0.8039
# Epoch 10/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 515s 3s/step - accuracy: 0.9577 - auc: 0.9865 - f1_score: 0.8649 - loss: 0.4098 - precision: 0.9175 - recall: 0.8201 - val_accuracy: 0.9598 - val_auc: 0.9882 - val_f1_score: 0.8699 - val_loss: 0.3978 - val_precision: 0.9348 - val_recall: 0.8157
# Epoch 11/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 514s 3s/step - accuracy: 0.9616 - auc: 0.9883 - f1_score: 0.8776 - loss: 0.3818 - precision: 0.9283 - recall: 0.8341 - val_accuracy: 0.9609 - val_auc: 0.9879 - val_f1_score: 0.8746 - val_loss: 0.3872 - val_precision: 0.9315 - val_recall: 0.8265
# Epoch 12/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 515s 3s/step - accuracy: 0.9619 - auc: 0.9890 - f1_score: 0.8791 - loss: 0.3667 - precision: 0.9279 - recall: 0.8366 - val_accuracy: 0.9626 - val_auc: 0.9885 - val_f1_score: 0.8804 - val_loss: 0.3734 - val_precision: 0.9322 - val_recall: 0.8363
# Epoch 13/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 516s 3s/step - accuracy: 0.9640 - auc: 0.9897 - f1_score: 0.8868 - loss: 0.3519 - precision: 0.9289 - recall: 0.8490 - val_accuracy: 0.9624 - val_auc: 0.9889 - val_f1_score: 0.8795 - val_loss: 0.3631 - val_precision: 0.9303 - val_recall: 0.8373
# Epoch 14/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 511s 3s/step - accuracy: 0.9630 - auc: 0.9891 - f1_score: 0.8835 - loss: 0.3565 - precision: 0.9242 - recall: 0.8474 - val_accuracy: 0.9642 - val_auc: 0.9894 - val_f1_score: 0.8864 - val_loss: 0.3534 - val_precision: 0.9339 - val_recall: 0.8451
# Epoch 15/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 514s 3s/step - accuracy: 0.9666 - auc: 0.9907 - f1_score: 0.8959 - loss: 0.3282 - precision: 0.9316 - recall: 0.8633 - val_accuracy: 0.9655 - val_auc: 0.9895 - val_f1_score: 0.8908 - val_loss: 0.3467 - val_precision: 0.9345 - val_recall: 0.8529
# Epoch 16/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 517s 3s/step - accuracy: 0.9668 - auc: 0.9918 - f1_score: 0.8954 - loss: 0.3156 - precision: 0.9320 - recall: 0.8641 - val_accuracy: 0.9657 - val_auc: 0.9896 - val_f1_score: 0.8926 - val_loss: 0.3411 - val_precision: 0.9318 - val_recall: 0.8569
# Epoch 17/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 515s 3s/step - accuracy: 0.9680 - auc: 0.9916 - f1_score: 0.9003 - loss: 0.3120 - precision: 0.9329 - recall: 0.8709 - val_accuracy: 0.9632 - val_auc: 0.9894 - val_f1_score: 0.8849 - val_loss: 0.3405 - val_precision: 0.9215 - val_recall: 0.8520
# Epoch 18/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 515s 3s/step - accuracy: 0.9719 - auc: 0.9934 - f1_score: 0.9125 - loss: 0.2872 - precision: 0.9445 - recall: 0.8830 - val_accuracy: 0.9665 - val_auc: 0.9902 - val_f1_score: 0.8956 - val_loss: 0.3285 - val_precision: 0.9303 - val_recall: 0.8637
# Epoch 19/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 511s 3s/step - accuracy: 0.9704 - auc: 0.9931 - f1_score: 0.9080 - loss: 0.2855 - precision: 0.9377 - recall: 0.8811 - val_accuracy: 0.9665 - val_auc: 0.9903 - val_f1_score: 0.8955 - val_loss: 0.3238 - val_precision: 0.9294 - val_recall: 0.8647
# Epoch 20/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 509s 3s/step - accuracy: 0.9678 - auc: 0.9920 - f1_score: 0.8999 - loss: 0.2986 - precision: 0.9310 - recall: 0.8712 - val_accuracy: 0.9667 - val_auc: 0.9903 - val_f1_score: 0.8959 - val_loss: 0.3215 - val_precision: 0.9286 - val_recall: 0.8667
# Epoch 21/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 512s 3s/step - accuracy: 0.9690 - auc: 0.9928 - f1_score: 0.9044 - loss: 0.2870 - precision: 0.9296 - recall: 0.8810 - val_accuracy: 0.9654 - val_auc: 0.9902 - val_f1_score: 0.8923 - val_loss: 0.3200 - val_precision: 0.9217 - val_recall: 0.8657
# Epoch 22/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 513s 3s/step - accuracy: 0.9714 - auc: 0.9933 - f1_score: 0.9110 - loss: 0.2784 - precision: 0.9399 - recall: 0.8849 - val_accuracy: 0.9657 - val_auc: 0.9901 - val_f1_score: 0.8941 - val_loss: 0.3182 - val_precision: 0.9201 - val_recall: 0.8696
# Epoch 23/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 539s 4s/step - accuracy: 0.9698 - auc: 0.9929 - f1_score: 0.9063 - loss: 0.2808 - precision: 0.9336 - recall: 0.8815 - val_accuracy: 0.9655 - val_auc: 0.9905 - val_f1_score: 0.8931 - val_loss: 0.3135 - val_precision: 0.9218 - val_recall: 0.8667
# Epoch 24/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 662s 4s/step - accuracy: 0.9729 - auc: 0.9942 - f1_score: 0.9160 - loss: 0.2601 - precision: 0.9425 - recall: 0.8915 - val_accuracy: 0.9675 - val_auc: 0.9908 - val_f1_score: 0.8996 - val_loss: 0.3068 - val_precision: 0.9254 - val_recall: 0.8755
# Epoch 25/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 629s 4s/step - accuracy: 0.9730 - auc: 0.9941 - f1_score: 0.9163 - loss: 0.2586 - precision: 0.9420 - recall: 0.8929 - val_accuracy: 0.9660 - val_auc: 0.9907 - val_f1_score: 0.8950 - val_loss: 0.3064 - val_precision: 0.9212 - val_recall: 0.8706
# Epoch 26/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 621s 4s/step - accuracy: 0.9748 - auc: 0.9948 - f1_score: 0.9220 - loss: 0.2509 - precision: 0.9469 - recall: 0.8990 - val_accuracy: 0.9683 - val_auc: 0.9910 - val_f1_score: 0.9020 - val_loss: 0.3016 - val_precision: 0.9275 - val_recall: 0.8784
# Epoch 27/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 609s 4s/step - accuracy: 0.9741 - auc: 0.9948 - f1_score: 0.9197 - loss: 0.2457 - precision: 0.9445 - recall: 0.8974 - val_accuracy: 0.9686 - val_auc: 0.9911 - val_f1_score: 0.9027 - val_loss: 0.2995 - val_precision: 0.9286 - val_recall: 0.8794
# Epoch 28/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 589s 4s/step - accuracy: 0.9755 - auc: 0.9954 - f1_score: 0.9244 - loss: 0.2321 - precision: 0.9457 - recall: 0.9052 - val_accuracy: 0.9678 - val_auc: 0.9910 - val_f1_score: 0.9001 - val_loss: 0.2988 - val_precision: 0.9247 - val_recall: 0.8784
# Epoch 29/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 540s 4s/step - accuracy: 0.9767 - auc: 0.9955 - f1_score: 0.9281 - loss: 0.2293 - precision: 0.9489 - recall: 0.9088 - val_accuracy: 0.9678 - val_auc: 0.9912 - val_f1_score: 0.9004 - val_loss: 0.2951 - val_precision: 0.9229 - val_recall: 0.8804
# Epoch 30/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 538s 4s/step - accuracy: 0.9759 - auc: 0.9948 - f1_score: 0.9258 - loss: 0.2419 - precision: 0.9482 - recall: 0.9049 - val_accuracy: 0.9690 - val_auc: 0.9910 - val_f1_score: 0.9046 - val_loss: 0.2924 - val_precision: 0.9261 - val_recall: 0.8843
# Epoch 31/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 544s 4s/step - accuracy: 0.9753 - auc: 0.9952 - f1_score: 0.9242 - loss: 0.2322 - precision: 0.9442 - recall: 0.9054 - val_accuracy: 0.9690 - val_auc: 0.9911 - val_f1_score: 0.9043 - val_loss: 0.2907 - val_precision: 0.9270 - val_recall: 0.8833
# Epoch 32/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 543s 4s/step - accuracy: 0.9760 - auc: 0.9948 - f1_score: 0.9262 - loss: 0.2350 - precision: 0.9465 - recall: 0.9073 - val_accuracy: 0.9686 - val_auc: 0.9913 - val_f1_score: 0.9034 - val_loss: 0.2906 - val_precision: 0.9251 - val_recall: 0.8833
# Epoch 33/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 542s 4s/step - accuracy: 0.9753 - auc: 0.9951 - f1_score: 0.9242 - loss: 0.2309 - precision: 0.9451 - recall: 0.9046 - val_accuracy: 0.9704 - val_auc: 0.9913 - val_f1_score: 0.9093 - val_loss: 0.2864 - val_precision: 0.9311 - val_recall: 0.8882
# Epoch 34/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 549s 4s/step - accuracy: 0.9767 - auc: 0.9959 - f1_score: 0.9284 - loss: 0.2196 - precision: 0.9478 - recall: 0.9103 - val_accuracy: 0.9698 - val_auc: 0.9912 - val_f1_score: 0.9070 - val_loss: 0.2864 - val_precision: 0.9273 - val_recall: 0.8882
# Epoch 35/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 546s 4s/step - accuracy: 0.9761 - auc: 0.9955 - f1_score: 0.9264 - loss: 0.2235 - precision: 0.9481 - recall: 0.9061 - val_accuracy: 0.9696 - val_auc: 0.9912 - val_f1_score: 0.9066 - val_loss: 0.2851 - val_precision: 0.9273 - val_recall: 0.8873
# Epoch 36/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 545s 4s/step - accuracy: 0.9759 - auc: 0.9953 - f1_score: 0.9261 - loss: 0.2258 - precision: 0.9437 - recall: 0.9093 - val_accuracy: 0.9704 - val_auc: 0.9914 - val_f1_score: 0.9089 - val_loss: 0.2816 - val_precision: 0.9311 - val_recall: 0.8882
# Epoch 37/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 544s 4s/step - accuracy: 0.9777 - auc: 0.9961 - f1_score: 0.9315 - loss: 0.2124 - precision: 0.9481 - recall: 0.9162 - val_accuracy: 0.9691 - val_auc: 0.9911 - val_f1_score: 0.9046 - val_loss: 0.2846 - val_precision: 0.9262 - val_recall: 0.8853
# Epoch 38/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 551s 4s/step - accuracy: 0.9779 - auc: 0.9962 - f1_score: 0.9320 - loss: 0.2116 - precision: 0.9525 - recall: 0.9129 - val_accuracy: 0.9691 - val_auc: 0.9913 - val_f1_score: 0.9048 - val_loss: 0.2825 - val_precision: 0.9262 - val_recall: 0.8853
# Epoch 39/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 551s 4s/step - accuracy: 0.9796 - auc: 0.9965 - f1_score: 0.9375 - loss: 0.2022 - precision: 0.9525 - recall: 0.9235 - val_accuracy: 0.9704 - val_auc: 0.9915 - val_f1_score: 0.9089 - val_loss: 0.2789 - val_precision: 0.9303 - val_recall: 0.8892
# Epoch 40/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 528s 4s/step - accuracy: 0.9783 - auc: 0.9960 - f1_score: 0.9334 - loss: 0.2106 - precision: 0.9514 - recall: 0.9167 - val_accuracy: 0.9699 - val_auc: 0.9915 - val_f1_score: 0.9074 - val_loss: 0.2789 - val_precision: 0.9300 - val_recall: 0.8863
# Epoch 41/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 531s 4s/step - accuracy: 0.9788 - auc: 0.9963 - f1_score: 0.9353 - loss: 0.2062 - precision: 0.9502 - recall: 0.9212 - val_accuracy: 0.9696 - val_auc: 0.9913 - val_f1_score: 0.9062 - val_loss: 0.2796 - val_precision: 0.9281 - val_recall: 0.8863
# Epoch 42/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 534s 4s/step - accuracy: 0.9790 - auc: 0.9961 - f1_score: 0.9354 - loss: 0.2036 - precision: 0.9507 - recall: 0.9220 - val_accuracy: 0.9699 - val_auc: 0.9915 - val_f1_score: 0.9071 - val_loss: 0.2760 - val_precision: 0.9274 - val_recall: 0.8892
# Epoch 43/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 531s 4s/step - accuracy: 0.9804 - auc: 0.9970 - f1_score: 0.9397 - loss: 0.1899 - precision: 0.9556 - recall: 0.9251 - val_accuracy: 0.9703 - val_auc: 0.9915 - val_f1_score: 0.9086 - val_loss: 0.2755 - val_precision: 0.9302 - val_recall: 0.8882
# Epoch 44/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 531s 4s/step - accuracy: 0.9809 - auc: 0.9966 - f1_score: 0.9414 - loss: 0.1959 - precision: 0.9557 - recall: 0.9288 - val_accuracy: 0.9703 - val_auc: 0.9916 - val_f1_score: 0.9086 - val_loss: 0.2743 - val_precision: 0.9302 - val_recall: 0.8882
# Epoch 45/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 526s 4s/step - accuracy: 0.9784 - auc: 0.9964 - f1_score: 0.9340 - loss: 0.2017 - precision: 0.9488 - recall: 0.9201 - val_accuracy: 0.9706 - val_auc: 0.9916 - val_f1_score: 0.9092 - val_loss: 0.2737 - val_precision: 0.9303 - val_recall: 0.8902
# Epoch 46/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 526s 4s/step - accuracy: 0.9808 - auc: 0.9968 - f1_score: 0.9410 - loss: 0.1914 - precision: 0.9572 - recall: 0.9260 - val_accuracy: 0.9714 - val_auc: 0.9918 - val_f1_score: 0.9115 - val_loss: 0.2695 - val_precision: 0.9324 - val_recall: 0.8931
# Epoch 47/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 527s 4s/step - accuracy: 0.9803 - auc: 0.9969 - f1_score: 0.9396 - loss: 0.1904 - precision: 0.9573 - recall: 0.9230 - val_accuracy: 0.9706 - val_auc: 0.9918 - val_f1_score: 0.9091 - val_loss: 0.2697 - val_precision: 0.9303 - val_recall: 0.8902
# Epoch 48/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 529s 4s/step - accuracy: 0.9815 - auc: 0.9970 - f1_score: 0.9432 - loss: 0.1834 - precision: 0.9569 - recall: 0.9307 - val_accuracy: 0.9690 - val_auc: 0.9915 - val_f1_score: 0.9048 - val_loss: 0.2737 - val_precision: 0.9226 - val_recall: 0.8882
# Epoch 49/300
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 530s 4s/step - accuracy: 0.9821 - auc: 0.9973 - f1_score: 0.9454 - loss: 0.1760 - precision: 0.9575 - recall: 0.9340 - val_accuracy: 0.9706 - val_auc: 0.9918 - val_f1_score: 0.9098 - val_loss: 0.2696 - val_precision: 0.9294 - val_recall: 0.8912

# %% [markdown]
# Result

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 96.03%

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt 
def Train_Val_plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):
    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(20, 5))
    fig.suptitle("VISUALIZE THE PERFORMANCE MATRICS")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1 Score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 Score')
    ax5.legend(['training', 'validation'])
    plt.show()

# %%
Train_Val_plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        Buras       0.90      0.90      0.90       170
#      Dangkot       0.84      0.76      0.80       170
#        Gogos       0.94      0.93      0.93       170
#     Kapurung       0.89      0.91      0.90       170
#        Sokko       0.86      0.88      0.87       170
#    Sop Konro       0.85      0.89      0.87       170
#
#     accuracy                           0.88      1020
#    macro avg       0.88      0.88      0.88      1020
# weighted avg       0.88      0.88      0.88      1020

# %%
# Import required libraries
import seaborn as sns

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_images.class_indices.keys(), yticklabels=test_images.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Saving the model
model.save('Percobaan2(5)_Xception.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Saving the model
# ----> 2 model.save('Percobaan2(5)_Xception.h5')
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %% [markdown]
# Deteksi

# %%
import numpy as np
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.mobilenet_v2 import preprocess_input
import matplotlib.pyplot as plt

# Load the custom MobileNetV2 model
model = load_model("D:\Kuliah Semester 6\Jurnal\Materi\CNN\Codingan\Percobaan2(5)_Xception.h5")

# Define the class names
class_names = ['Buras', 'Dangkot', 'Gogos', 'Kapurung', 'Sokko', 'Sop Konro']

# Define the path to your image
image_path = r"E:\Dataset\BURAS.jpg"

# Load and preprocess the image
img = image.load_img(image_path, target_size=(224, 224))  # Sesuaikan ukuran dengan ukuran input model Anda
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make prediction
preds = model.predict(x)

# Check the shape of the predictions
print("Predictions shape:", preds.shape)

# Get the index of the highest probability prediction
pred_index = np.argmax(preds)

# Initialize the predicted class variable
predicted_class = "Predicted index is out of range"

# Check if pred_index is within the range of class_names
if pred_index < len(class_names):
    # Get the predicted class label
    predicted_class = class_names[pred_index]

# Print the predicted class label
print("Predicted class:", predicted_class)

# Display the image along with the predicted class
plt.imshow(image.load_img(image_path))
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predictions shape: (1, 6)
# Predicted class: Kapurung
