# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report

# %%
image_dir = Path(r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset")

# %% [markdown]
# Buat File Dataframe

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

images = pd.concat([filepaths, labels], axis=1)

category_samples = []
for category in images['Label'].unique():
    category_slice = images.query("Label == @category")
    # Ambil sampel dari setiap kategori dengan maksimum 600 gambar
    category_samples.append(category_slice.sample(min(6000, len(category_slice)), random_state=1, replace=False))

image_df = pd.concat(category_samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                                Filepath      Label
# 0     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 1     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Gogos
# 2     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...  Sop Konro
# 3     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 4     D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# ...                                                 ...        ...
# 6793  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6794  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
# 6795  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...   Kapurung
# 6796  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Buras
# 6797  D:\Kuliah Semester 6\Jurnal\Materi\CNN\Dataset...      Sokko
#
# [6798 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# Label
# Gogos        1133
# Sop Konro    1133
# Kapurung     1133
# Buras        1133
# Dangkot      1133
# Sokko        1133
# Name: count, dtype: int64

# %%
train_dir = r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\train'
val_dir =r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\val'
test_dir=r'D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test'

# %% [markdown]
# Buat Train Generator

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_images = train_generator.flow_from_directory(
    directory=train_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=64,
    shuffle=True,
    seed=42
    #subset='training'
)

val_images = train_generator.flow_from_directory(
    directory=val_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=64,
    shuffle=True,
    seed=42
    #subset='validation'
)

test_images = test_generator.flow_from_directory(
    directory=test_dir,
    #x_col='Filepath',
    #y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=64,
    shuffle=False
)
# Out:
# Found 4758 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.
# Found 1020 images belonging to 6 classes.

# %% [markdown]
# Modelling

# %%
pretrained_model = EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='swish')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='swish')(x)

outputs = tf.keras.layers.Dense(6, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)


#print(model.summary())

# %% [markdown]
# Training

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
model.compile(
    optimizer='adagrad',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc'),
        f1_score,
    ]
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=300,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/300
# c:\Program Files\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.8333 - auc: 0.4614 - f1_score: 0.0000e+00 - loss: 1.8190 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8333 - val_auc: 0.6525 - val_f1_score: 0.0000e+00 - val_loss: 1.7374 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.8333 - auc: 0.6946 - f1_score: 0.0000e+00 - loss: 1.7164 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8333 - val_auc: 0.8234 - val_f1_score: 0.0000e+00 - val_loss: 1.6416 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.8333 - auc: 0.8351 - f1_score: 0.0000e+00 - loss: 1.6231 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8333 - val_auc: 0.8981 - val_f1_score: 0.0000e+00 - val_loss: 1.5430 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.8333 - auc: 0.8985 - f1_score: 0.0000e+00 - loss: 1.5255 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8333 - val_auc: 0.9291 - val_f1_score: 0.0000e+00 - val_loss: 1.4368 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.8337 - auc: 0.9225 - f1_score: 0.0043 - loss: 1.4215 - precision: 0.9868 - recall: 0.0022 - val_accuracy: 0.8345 - val_auc: 0.9439 - val_f1_score: 0.0135 - val_loss: 1.3217 - val_precision: 1.0000 - val_recall: 0.0069
# Epoch 6/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.8358 - auc: 0.9362 - f1_score: 0.0292 - loss: 1.3059 - precision: 0.9868 - recall: 0.0150 - val_accuracy: 0.8392 - val_auc: 0.9534 - val_f1_score: 0.0694 - val_loss: 1.2010 - val_precision: 0.9737 - val_recall: 0.0363
# Epoch 7/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.8444 - auc: 0.9499 - f1_score: 0.1243 - loss: 1.1827 - precision: 0.9824 - recall: 0.0675 - val_accuracy: 0.8542 - val_auc: 0.9603 - val_f1_score: 0.2236 - val_loss: 1.0817 - val_precision: 0.9848 - val_recall: 0.1275
# Epoch 8/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.8583 - auc: 0.9532 - f1_score: 0.2619 - loss: 1.0737 - precision: 0.9808 - recall: 0.1525 - val_accuracy: 0.8724 - val_auc: 0.9658 - val_f1_score: 0.3832 - val_loss: 0.9707 - val_precision: 0.9799 - val_recall: 0.2392
# Epoch 9/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.8747 - auc: 0.9617 - f1_score: 0.3973 - loss: 0.9635 - precision: 0.9850 - recall: 0.2524 - val_accuracy: 0.8917 - val_auc: 0.9705 - val_f1_score: 0.5227 - val_loss: 0.8720 - val_precision: 0.9811 - val_recall: 0.3569
# Epoch 10/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8926 - auc: 0.9655 - f1_score: 0.5299 - loss: 0.8782 - precision: 0.9742 - recall: 0.3653 - val_accuracy: 0.9072 - val_auc: 0.9743 - val_f1_score: 0.6204 - val_loss: 0.7871 - val_precision: 0.9650 - val_recall: 0.4598
# Epoch 11/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9082 - auc: 0.9685 - f1_score: 0.6265 - loss: 0.8011 - precision: 0.9655 - recall: 0.4658 - val_accuracy: 0.9209 - val_auc: 0.9774 - val_f1_score: 0.6953 - val_loss: 0.7150 - val_precision: 0.9653 - val_recall: 0.5451
# Epoch 12/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9201 - auc: 0.9726 - f1_score: 0.6913 - loss: 0.7328 - precision: 0.9633 - recall: 0.5416 - val_accuracy: 0.9322 - val_auc: 0.9799 - val_f1_score: 0.7511 - val_loss: 0.6541 - val_precision: 0.9590 - val_recall: 0.6196
# Epoch 13/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9259 - auc: 0.9725 - f1_score: 0.7249 - loss: 0.6940 - precision: 0.9426 - recall: 0.5911 - val_accuracy: 0.9395 - val_auc: 0.9819 - val_f1_score: 0.7867 - val_loss: 0.6027 - val_precision: 0.9501 - val_recall: 0.6725
# Epoch 14/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9363 - auc: 0.9766 - f1_score: 0.7724 - loss: 0.6315 - precision: 0.9463 - recall: 0.6551 - val_accuracy: 0.9458 - val_auc: 0.9836 - val_f1_score: 0.8128 - val_loss: 0.5591 - val_precision: 0.9491 - val_recall: 0.7127
# Epoch 15/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9434 - auc: 0.9805 - f1_score: 0.8053 - loss: 0.5767 - precision: 0.9430 - recall: 0.7028 - val_accuracy: 0.9487 - val_auc: 0.9849 - val_f1_score: 0.8263 - val_loss: 0.5221 - val_precision: 0.9413 - val_recall: 0.7382
# Epoch 16/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9461 - auc: 0.9826 - f1_score: 0.8187 - loss: 0.5417 - precision: 0.9357 - recall: 0.7267 - val_accuracy: 0.9503 - val_auc: 0.9861 - val_f1_score: 0.8346 - val_loss: 0.4905 - val_precision: 0.9324 - val_recall: 0.7569
# Epoch 17/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9471 - auc: 0.9818 - f1_score: 0.8220 - loss: 0.5231 - precision: 0.9280 - recall: 0.7397 - val_accuracy: 0.9536 - val_auc: 0.9871 - val_f1_score: 0.8476 - val_loss: 0.4630 - val_precision: 0.9340 - val_recall: 0.7765
# Epoch 18/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9543 - auc: 0.9851 - f1_score: 0.8489 - loss: 0.4803 - precision: 0.9403 - recall: 0.7750 - val_accuracy: 0.9564 - val_auc: 0.9879 - val_f1_score: 0.8577 - val_loss: 0.4388 - val_precision: 0.9343 - val_recall: 0.7941
# Epoch 19/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9541 - auc: 0.9856 - f1_score: 0.8491 - loss: 0.4586 - precision: 0.9308 - recall: 0.7826 - val_accuracy: 0.9577 - val_auc: 0.9886 - val_f1_score: 0.8634 - val_loss: 0.4189 - val_precision: 0.9309 - val_recall: 0.8059
# Epoch 20/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9568 - auc: 0.9860 - f1_score: 0.8606 - loss: 0.4354 - precision: 0.9240 - recall: 0.8070 - val_accuracy: 0.9596 - val_auc: 0.9892 - val_f1_score: 0.8707 - val_loss: 0.4008 - val_precision: 0.9318 - val_recall: 0.8176
# Epoch 21/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9561 - auc: 0.9847 - f1_score: 0.8569 - loss: 0.4441 - precision: 0.9241 - recall: 0.8027 - val_accuracy: 0.9608 - val_auc: 0.9896 - val_f1_score: 0.8742 - val_loss: 0.3857 - val_precision: 0.9295 - val_recall: 0.8275
# Epoch 22/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9605 - auc: 0.9884 - f1_score: 0.8754 - loss: 0.3966 - precision: 0.9305 - recall: 0.8247 - val_accuracy: 0.9618 - val_auc: 0.9901 - val_f1_score: 0.8790 - val_loss: 0.3715 - val_precision: 0.9290 - val_recall: 0.8343
# Epoch 23/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9609 - auc: 0.9885 - f1_score: 0.8760 - loss: 0.3884 - precision: 0.9302 - recall: 0.8274 - val_accuracy: 0.9623 - val_auc: 0.9906 - val_f1_score: 0.8806 - val_loss: 0.3581 - val_precision: 0.9256 - val_recall: 0.8412
# Epoch 24/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9607 - auc: 0.9885 - f1_score: 0.8758 - loss: 0.3826 - precision: 0.9227 - recall: 0.8338 - val_accuracy: 0.9634 - val_auc: 0.9909 - val_f1_score: 0.8851 - val_loss: 0.3474 - val_precision: 0.9280 - val_recall: 0.8461
# Epoch 25/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9629 - auc: 0.9893 - f1_score: 0.8821 - loss: 0.3692 - precision: 0.9326 - recall: 0.8382 - val_accuracy: 0.9650 - val_auc: 0.9912 - val_f1_score: 0.8906 - val_loss: 0.3381 - val_precision: 0.9296 - val_recall: 0.8549
# Epoch 26/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9612 - auc: 0.9892 - f1_score: 0.8776 - loss: 0.3639 - precision: 0.9241 - recall: 0.8362 - val_accuracy: 0.9654 - val_auc: 0.9915 - val_f1_score: 0.8916 - val_loss: 0.3288 - val_precision: 0.9289 - val_recall: 0.8578
# Epoch 27/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9626 - auc: 0.9894 - f1_score: 0.8824 - loss: 0.3545 - precision: 0.9253 - recall: 0.8438 - val_accuracy: 0.9667 - val_auc: 0.9918 - val_f1_score: 0.8965 - val_loss: 0.3204 - val_precision: 0.9286 - val_recall: 0.8667
# Epoch 28/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9648 - auc: 0.9901 - f1_score: 0.8879 - loss: 0.3409 - precision: 0.9301 - recall: 0.8527 - val_accuracy: 0.9667 - val_auc: 0.9920 - val_f1_score: 0.8962 - val_loss: 0.3131 - val_precision: 0.9277 - val_recall: 0.8676
# Epoch 29/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9663 - auc: 0.9911 - f1_score: 0.8949 - loss: 0.3281 - precision: 0.9315 - recall: 0.8611 - val_accuracy: 0.9672 - val_auc: 0.9922 - val_f1_score: 0.8981 - val_loss: 0.3060 - val_precision: 0.9288 - val_recall: 0.8696
# Epoch 30/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9669 - auc: 0.9906 - f1_score: 0.8970 - loss: 0.3237 - precision: 0.9305 - recall: 0.8661 - val_accuracy: 0.9673 - val_auc: 0.9924 - val_f1_score: 0.8987 - val_loss: 0.3003 - val_precision: 0.9289 - val_recall: 0.8706
# Epoch 31/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9671 - auc: 0.9912 - f1_score: 0.8979 - loss: 0.3135 - precision: 0.9288 - recall: 0.8693 - val_accuracy: 0.9676 - val_auc: 0.9926 - val_f1_score: 0.8996 - val_loss: 0.2947 - val_precision: 0.9290 - val_recall: 0.8725
# Epoch 32/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9666 - auc: 0.9908 - f1_score: 0.8957 - loss: 0.3188 - precision: 0.9311 - recall: 0.8634 - val_accuracy: 0.9680 - val_auc: 0.9927 - val_f1_score: 0.9007 - val_loss: 0.2896 - val_precision: 0.9301 - val_recall: 0.8735
# Epoch 33/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9644 - auc: 0.9909 - f1_score: 0.8887 - loss: 0.3127 - precision: 0.9224 - recall: 0.8583 - val_accuracy: 0.9680 - val_auc: 0.9929 - val_f1_score: 0.9012 - val_loss: 0.2849 - val_precision: 0.9283 - val_recall: 0.8755
# Epoch 34/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9689 - auc: 0.9916 - f1_score: 0.9038 - loss: 0.3005 - precision: 0.9301 - recall: 0.8797 - val_accuracy: 0.9683 - val_auc: 0.9929 - val_f1_score: 0.9021 - val_loss: 0.2814 - val_precision: 0.9293 - val_recall: 0.8765
# Epoch 35/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9694 - auc: 0.9926 - f1_score: 0.9061 - loss: 0.2811 - precision: 0.9307 - recall: 0.8822 - val_accuracy: 0.9688 - val_auc: 0.9931 - val_f1_score: 0.9036 - val_loss: 0.2767 - val_precision: 0.9278 - val_recall: 0.8814
# Epoch 36/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9673 - auc: 0.9926 - f1_score: 0.8951 - loss: 0.2860 - precision: 0.9315 - recall: 0.8675 - val_accuracy: 0.9686 - val_auc: 0.9932 - val_f1_score: 0.9029 - val_loss: 0.2729 - val_precision: 0.9268 - val_recall: 0.8814
# Epoch 37/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9702 - auc: 0.9930 - f1_score: 0.9077 - loss: 0.2778 - precision: 0.9334 - recall: 0.8844 - val_accuracy: 0.9691 - val_auc: 0.9933 - val_f1_score: 0.9048 - val_loss: 0.2694 - val_precision: 0.9279 - val_recall: 0.8833
# Epoch 38/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9711 - auc: 0.9924 - f1_score: 0.9110 - loss: 0.2779 - precision: 0.9358 - recall: 0.8874 - val_accuracy: 0.9693 - val_auc: 0.9934 - val_f1_score: 0.9053 - val_loss: 0.2655 - val_precision: 0.9298 - val_recall: 0.8824
# Epoch 39/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9722 - auc: 0.9937 - f1_score: 0.9145 - loss: 0.2632 - precision: 0.9394 - recall: 0.8906 - val_accuracy: 0.9696 - val_auc: 0.9935 - val_f1_score: 0.9066 - val_loss: 0.2628 - val_precision: 0.9281 - val_recall: 0.8863
# Epoch 40/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9713 - auc: 0.9927 - f1_score: 0.9123 - loss: 0.2744 - precision: 0.9376 - recall: 0.8867 - val_accuracy: 0.9699 - val_auc: 0.9936 - val_f1_score: 0.9075 - val_loss: 0.2598 - val_precision: 0.9292 - val_recall: 0.8873
# Epoch 41/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9720 - auc: 0.9945 - f1_score: 0.9134 - loss: 0.2533 - precision: 0.9385 - recall: 0.8902 - val_accuracy: 0.9703 - val_auc: 0.9937 - val_f1_score: 0.9090 - val_loss: 0.2573 - val_precision: 0.9293 - val_recall: 0.8892
# Epoch 42/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9718 - auc: 0.9941 - f1_score: 0.9133 - loss: 0.2517 - precision: 0.9348 - recall: 0.8931 - val_accuracy: 0.9701 - val_auc: 0.9938 - val_f1_score: 0.9085 - val_loss: 0.2549 - val_precision: 0.9275 - val_recall: 0.8902
# Epoch 43/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9716 - auc: 0.9941 - f1_score: 0.9124 - loss: 0.2520 - precision: 0.9379 - recall: 0.8886 - val_accuracy: 0.9714 - val_auc: 0.9939 - val_f1_score: 0.9126 - val_loss: 0.2523 - val_precision: 0.9316 - val_recall: 0.8941
# Epoch 44/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9721 - auc: 0.9939 - f1_score: 0.9142 - loss: 0.2482 - precision: 0.9364 - recall: 0.8935 - val_accuracy: 0.9712 - val_auc: 0.9940 - val_f1_score: 0.9119 - val_loss: 0.2494 - val_precision: 0.9306 - val_recall: 0.8941
# Epoch 45/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9723 - auc: 0.9934 - f1_score: 0.9149 - loss: 0.2514 - precision: 0.9348 - recall: 0.8963 - val_accuracy: 0.9711 - val_auc: 0.9941 - val_f1_score: 0.9114 - val_loss: 0.2476 - val_precision: 0.9305 - val_recall: 0.8931
# Epoch 46/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9741 - auc: 0.9950 - f1_score: 0.9205 - loss: 0.2350 - precision: 0.9419 - recall: 0.9004 - val_accuracy: 0.9716 - val_auc: 0.9938 - val_f1_score: 0.9130 - val_loss: 0.2444 - val_precision: 0.9316 - val_recall: 0.8951
# Epoch 47/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9735 - auc: 0.9941 - f1_score: 0.9188 - loss: 0.2452 - precision: 0.9386 - recall: 0.9000 - val_accuracy: 0.9719 - val_auc: 0.9939 - val_f1_score: 0.9138 - val_loss: 0.2426 - val_precision: 0.9318 - val_recall: 0.8971
# Epoch 48/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9731 - auc: 0.9939 - f1_score: 0.9174 - loss: 0.2463 - precision: 0.9401 - recall: 0.8955 - val_accuracy: 0.9721 - val_auc: 0.9939 - val_f1_score: 0.9146 - val_loss: 0.2410 - val_precision: 0.9318 - val_recall: 0.8980
# Epoch 49/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9755 - auc: 0.9950 - f1_score: 0.9247 - loss: 0.2326 - precision: 0.9458 - recall: 0.9050 - val_accuracy: 0.9722 - val_auc: 0.9940 - val_f1_score: 0.9151 - val_loss: 0.2392 - val_precision: 0.9319 - val_recall: 0.8990
# Epoch 50/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9740 - auc: 0.9945 - f1_score: 0.9204 - loss: 0.2356 - precision: 0.9393 - recall: 0.9026 - val_accuracy: 0.9724 - val_auc: 0.9940 - val_f1_score: 0.9154 - val_loss: 0.2380 - val_precision: 0.9329 - val_recall: 0.8990
# Epoch 51/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9747 - auc: 0.9945 - f1_score: 0.9220 - loss: 0.2337 - precision: 0.9396 - recall: 0.9064 - val_accuracy: 0.9730 - val_auc: 0.9941 - val_f1_score: 0.9177 - val_loss: 0.2366 - val_precision: 0.9349 - val_recall: 0.9010
# Epoch 52/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9750 - auc: 0.9947 - f1_score: 0.9243 - loss: 0.2265 - precision: 0.9416 - recall: 0.9063 - val_accuracy: 0.9730 - val_auc: 0.9942 - val_f1_score: 0.9176 - val_loss: 0.2343 - val_precision: 0.9349 - val_recall: 0.9010
# Epoch 53/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9750 - auc: 0.9943 - f1_score: 0.9241 - loss: 0.2316 - precision: 0.9396 - recall: 0.9086 - val_accuracy: 0.9729 - val_auc: 0.9943 - val_f1_score: 0.9163 - val_loss: 0.2323 - val_precision: 0.9348 - val_recall: 0.9000
# Epoch 54/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9746 - auc: 0.9947 - f1_score: 0.9223 - loss: 0.2333 - precision: 0.9416 - recall: 0.9034 - val_accuracy: 0.9732 - val_auc: 0.9943 - val_f1_score: 0.9183 - val_loss: 0.2310 - val_precision: 0.9350 - val_recall: 0.9020
# Epoch 55/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9762 - auc: 0.9953 - f1_score: 0.9274 - loss: 0.2185 - precision: 0.9447 - recall: 0.9102 - val_accuracy: 0.9737 - val_auc: 0.9943 - val_f1_score: 0.9196 - val_loss: 0.2303 - val_precision: 0.9352 - val_recall: 0.9049
# Epoch 56/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9761 - auc: 0.9950 - f1_score: 0.9267 - loss: 0.2206 - precision: 0.9430 - recall: 0.9115 - val_accuracy: 0.9739 - val_auc: 0.9944 - val_f1_score: 0.9199 - val_loss: 0.2283 - val_precision: 0.9352 - val_recall: 0.9059
# Epoch 57/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9772 - auc: 0.9957 - f1_score: 0.9304 - loss: 0.2114 - precision: 0.9445 - recall: 0.9171 - val_accuracy: 0.9740 - val_auc: 0.9944 - val_f1_score: 0.9207 - val_loss: 0.2265 - val_precision: 0.9353 - val_recall: 0.9069
# Epoch 58/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9785 - auc: 0.9961 - f1_score: 0.9346 - loss: 0.2039 - precision: 0.9475 - recall: 0.9223 - val_accuracy: 0.9742 - val_auc: 0.9945 - val_f1_score: 0.9216 - val_loss: 0.2256 - val_precision: 0.9354 - val_recall: 0.9078
# Epoch 59/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9776 - auc: 0.9956 - f1_score: 0.9314 - loss: 0.2085 - precision: 0.9488 - recall: 0.9151 - val_accuracy: 0.9743 - val_auc: 0.9945 - val_f1_score: 0.9217 - val_loss: 0.2241 - val_precision: 0.9354 - val_recall: 0.9088
# Epoch 60/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9769 - auc: 0.9951 - f1_score: 0.9295 - loss: 0.2096 - precision: 0.9429 - recall: 0.9167 - val_accuracy: 0.9742 - val_auc: 0.9946 - val_f1_score: 0.9215 - val_loss: 0.2233 - val_precision: 0.9345 - val_recall: 0.9088
# Epoch 61/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.9757 - auc: 0.9953 - f1_score: 0.9261 - loss: 0.2150 - precision: 0.9400 - recall: 0.9121 - val_accuracy: 0.9740 - val_auc: 0.9946 - val_f1_score: 0.9211 - val_loss: 0.2224 - val_precision: 0.9335 - val_recall: 0.9088
# Epoch 62/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.9764 - auc: 0.9955 - f1_score: 0.9281 - loss: 0.2093 - precision: 0.9407 - recall: 0.9161 - val_accuracy: 0.9740 - val_auc: 0.9946 - val_f1_score: 0.9210 - val_loss: 0.2210 - val_precision: 0.9335 - val_recall: 0.9088
# Epoch 63/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 175s 2s/step - accuracy: 0.9795 - auc: 0.9959 - f1_score: 0.9372 - loss: 0.2023 - precision: 0.9511 - recall: 0.9243 - val_accuracy: 0.9742 - val_auc: 0.9947 - val_f1_score: 0.9213 - val_loss: 0.2197 - val_precision: 0.9345 - val_recall: 0.9088
# Epoch 64/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9777 - auc: 0.9964 - f1_score: 0.9318 - loss: 0.1967 - precision: 0.9456 - recall: 0.9189 - val_accuracy: 0.9740 - val_auc: 0.9947 - val_f1_score: 0.9207 - val_loss: 0.2185 - val_precision: 0.9335 - val_recall: 0.9088
# Epoch 65/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9785 - auc: 0.9960 - f1_score: 0.9343 - loss: 0.2030 - precision: 0.9480 - recall: 0.9213 - val_accuracy: 0.9750 - val_auc: 0.9948 - val_f1_score: 0.9240 - val_loss: 0.2177 - val_precision: 0.9366 - val_recall: 0.9118
# Epoch 66/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9788 - auc: 0.9960 - f1_score: 0.9360 - loss: 0.1932 - precision: 0.9489 - recall: 0.9226 - val_accuracy: 0.9739 - val_auc: 0.9948 - val_f1_score: 0.9205 - val_loss: 0.2169 - val_precision: 0.9335 - val_recall: 0.9078
# Epoch 67/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9746 - auc: 0.9948 - f1_score: 0.9227 - loss: 0.2145 - precision: 0.9371 - recall: 0.9089 - val_accuracy: 0.9750 - val_auc: 0.9948 - val_f1_score: 0.9240 - val_loss: 0.2157 - val_precision: 0.9366 - val_recall: 0.9118
# Epoch 68/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9776 - auc: 0.9958 - f1_score: 0.9308 - loss: 0.2030 - precision: 0.9463 - recall: 0.9175 - val_accuracy: 0.9748 - val_auc: 0.9948 - val_f1_score: 0.9234 - val_loss: 0.2146 - val_precision: 0.9356 - val_recall: 0.9118
# Epoch 69/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.9797 - auc: 0.9966 - f1_score: 0.9382 - loss: 0.1885 - precision: 0.9515 - recall: 0.9251 - val_accuracy: 0.9745 - val_auc: 0.9949 - val_f1_score: 0.9226 - val_loss: 0.2137 - val_precision: 0.9346 - val_recall: 0.9108
# Epoch 70/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.9789 - auc: 0.9962 - f1_score: 0.9352 - loss: 0.1957 - precision: 0.9506 - recall: 0.9211 - val_accuracy: 0.9740 - val_auc: 0.9949 - val_f1_score: 0.9208 - val_loss: 0.2136 - val_precision: 0.9327 - val_recall: 0.9098
# Epoch 71/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 173s 2s/step - accuracy: 0.9784 - auc: 0.9954 - f1_score: 0.9344 - loss: 0.1979 - precision: 0.9460 - recall: 0.9229 - val_accuracy: 0.9752 - val_auc: 0.9950 - val_f1_score: 0.9246 - val_loss: 0.2116 - val_precision: 0.9366 - val_recall: 0.9127
# Epoch 72/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.9810 - auc: 0.9970 - f1_score: 0.9427 - loss: 0.1771 - precision: 0.9533 - recall: 0.9318 - val_accuracy: 0.9750 - val_auc: 0.9950 - val_f1_score: 0.9239 - val_loss: 0.2107 - val_precision: 0.9357 - val_recall: 0.9127
# Epoch 73/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9757 - auc: 0.9957 - f1_score: 0.9262 - loss: 0.1976 - precision: 0.9389 - recall: 0.9137 - val_accuracy: 0.9755 - val_auc: 0.9950 - val_f1_score: 0.9254 - val_loss: 0.2103 - val_precision: 0.9367 - val_recall: 0.9147
# Epoch 74/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9811 - auc: 0.9970 - f1_score: 0.9424 - loss: 0.1769 - precision: 0.9523 - recall: 0.9331 - val_accuracy: 0.9750 - val_auc: 0.9950 - val_f1_score: 0.9240 - val_loss: 0.2101 - val_precision: 0.9348 - val_recall: 0.9137
# Epoch 75/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9809 - auc: 0.9969 - f1_score: 0.9418 - loss: 0.1750 - precision: 0.9533 - recall: 0.9312 - val_accuracy: 0.9748 - val_auc: 0.9951 - val_f1_score: 0.9236 - val_loss: 0.2088 - val_precision: 0.9347 - val_recall: 0.9127
# Epoch 76/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9811 - auc: 0.9968 - f1_score: 0.9423 - loss: 0.1770 - precision: 0.9547 - recall: 0.9307 - val_accuracy: 0.9752 - val_auc: 0.9951 - val_f1_score: 0.9245 - val_loss: 0.2082 - val_precision: 0.9357 - val_recall: 0.9137
# Epoch 77/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9805 - auc: 0.9968 - f1_score: 0.9411 - loss: 0.1773 - precision: 0.9522 - recall: 0.9299 - val_accuracy: 0.9752 - val_auc: 0.9951 - val_f1_score: 0.9245 - val_loss: 0.2072 - val_precision: 0.9357 - val_recall: 0.9137
# Epoch 78/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9813 - auc: 0.9964 - f1_score: 0.9429 - loss: 0.1816 - precision: 0.9555 - recall: 0.9313 - val_accuracy: 0.9752 - val_auc: 0.9951 - val_f1_score: 0.9244 - val_loss: 0.2068 - val_precision: 0.9357 - val_recall: 0.9137
# Epoch 79/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9795 - auc: 0.9963 - f1_score: 0.9376 - loss: 0.1853 - precision: 0.9494 - recall: 0.9264 - val_accuracy: 0.9753 - val_auc: 0.9952 - val_f1_score: 0.9249 - val_loss: 0.2059 - val_precision: 0.9367 - val_recall: 0.9137
# Epoch 80/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9817 - auc: 0.9967 - f1_score: 0.9430 - loss: 0.1771 - precision: 0.9566 - recall: 0.9326 - val_accuracy: 0.9752 - val_auc: 0.9952 - val_f1_score: 0.9247 - val_loss: 0.2056 - val_precision: 0.9349 - val_recall: 0.9147
# Epoch 81/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9796 - auc: 0.9960 - f1_score: 0.9383 - loss: 0.1840 - precision: 0.9485 - recall: 0.9282 - val_accuracy: 0.9752 - val_auc: 0.9952 - val_f1_score: 0.9248 - val_loss: 0.2046 - val_precision: 0.9349 - val_recall: 0.9147
# Epoch 82/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9819 - auc: 0.9973 - f1_score: 0.9451 - loss: 0.1670 - precision: 0.9545 - recall: 0.9361 - val_accuracy: 0.9753 - val_auc: 0.9953 - val_f1_score: 0.9254 - val_loss: 0.2040 - val_precision: 0.9358 - val_recall: 0.9147
# Epoch 83/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9821 - auc: 0.9974 - f1_score: 0.9457 - loss: 0.1662 - precision: 0.9569 - recall: 0.9348 - val_accuracy: 0.9752 - val_auc: 0.9953 - val_f1_score: 0.9242 - val_loss: 0.2038 - val_precision: 0.9357 - val_recall: 0.9137
# Epoch 84/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9801 - auc: 0.9969 - f1_score: 0.9396 - loss: 0.1758 - precision: 0.9494 - recall: 0.9299 - val_accuracy: 0.9755 - val_auc: 0.9953 - val_f1_score: 0.9257 - val_loss: 0.2030 - val_precision: 0.9359 - val_recall: 0.9157
# Epoch 85/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9821 - auc: 0.9970 - f1_score: 0.9463 - loss: 0.1706 - precision: 0.9540 - recall: 0.9376 - val_accuracy: 0.9757 - val_auc: 0.9953 - val_f1_score: 0.9262 - val_loss: 0.2023 - val_precision: 0.9368 - val_recall: 0.9157
# Epoch 86/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9796 - auc: 0.9972 - f1_score: 0.9376 - loss: 0.1705 - precision: 0.9469 - recall: 0.9297 - val_accuracy: 0.9757 - val_auc: 0.9953 - val_f1_score: 0.9261 - val_loss: 0.2019 - val_precision: 0.9368 - val_recall: 0.9157
# Epoch 87/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9808 - auc: 0.9970 - f1_score: 0.9416 - loss: 0.1707 - precision: 0.9525 - recall: 0.9314 - val_accuracy: 0.9755 - val_auc: 0.9954 - val_f1_score: 0.9259 - val_loss: 0.2012 - val_precision: 0.9359 - val_recall: 0.9157
# Epoch 88/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9830 - auc: 0.9970 - f1_score: 0.9485 - loss: 0.1679 - precision: 0.9576 - recall: 0.9396 - val_accuracy: 0.9757 - val_auc: 0.9954 - val_f1_score: 0.9261 - val_loss: 0.2010 - val_precision: 0.9368 - val_recall: 0.9157
# Epoch 89/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9814 - auc: 0.9966 - f1_score: 0.9437 - loss: 0.1730 - precision: 0.9522 - recall: 0.9353 - val_accuracy: 0.9757 - val_auc: 0.9954 - val_f1_score: 0.9259 - val_loss: 0.2003 - val_precision: 0.9368 - val_recall: 0.9157
# Epoch 90/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9817 - auc: 0.9972 - f1_score: 0.9433 - loss: 0.1673 - precision: 0.9555 - recall: 0.9339 - val_accuracy: 0.9760 - val_auc: 0.9954 - val_f1_score: 0.9270 - val_loss: 0.1996 - val_precision: 0.9369 - val_recall: 0.9176
# Epoch 91/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9834 - auc: 0.9973 - f1_score: 0.9500 - loss: 0.1612 - precision: 0.9588 - recall: 0.9408 - val_accuracy: 0.9760 - val_auc: 0.9955 - val_f1_score: 0.9272 - val_loss: 0.1986 - val_precision: 0.9378 - val_recall: 0.9167
# Epoch 92/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9834 - auc: 0.9974 - f1_score: 0.9497 - loss: 0.1585 - precision: 0.9577 - recall: 0.9418 - val_accuracy: 0.9763 - val_auc: 0.9954 - val_f1_score: 0.9281 - val_loss: 0.1984 - val_precision: 0.9388 - val_recall: 0.9176
# Epoch 93/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9840 - auc: 0.9972 - f1_score: 0.9499 - loss: 0.1575 - precision: 0.9595 - recall: 0.9437 - val_accuracy: 0.9763 - val_auc: 0.9955 - val_f1_score: 0.9281 - val_loss: 0.1987 - val_precision: 0.9379 - val_recall: 0.9186
# Epoch 94/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9820 - auc: 0.9973 - f1_score: 0.9454 - loss: 0.1636 - precision: 0.9556 - recall: 0.9355 - val_accuracy: 0.9760 - val_auc: 0.9955 - val_f1_score: 0.9270 - val_loss: 0.1973 - val_precision: 0.9369 - val_recall: 0.9176
# Epoch 95/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9834 - auc: 0.9970 - f1_score: 0.9498 - loss: 0.1591 - precision: 0.9579 - recall: 0.9421 - val_accuracy: 0.9763 - val_auc: 0.9955 - val_f1_score: 0.9283 - val_loss: 0.1975 - val_precision: 0.9379 - val_recall: 0.9186
# Epoch 96/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9814 - auc: 0.9972 - f1_score: 0.9437 - loss: 0.1641 - precision: 0.9537 - recall: 0.9340 - val_accuracy: 0.9761 - val_auc: 0.9955 - val_f1_score: 0.9276 - val_loss: 0.1971 - val_precision: 0.9370 - val_recall: 0.9186
# Epoch 97/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9830 - auc: 0.9974 - f1_score: 0.9484 - loss: 0.1588 - precision: 0.9590 - recall: 0.9378 - val_accuracy: 0.9765 - val_auc: 0.9955 - val_f1_score: 0.9286 - val_loss: 0.1968 - val_precision: 0.9380 - val_recall: 0.9196
# Epoch 98/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9826 - auc: 0.9974 - f1_score: 0.9471 - loss: 0.1567 - precision: 0.9558 - recall: 0.9388 - val_accuracy: 0.9768 - val_auc: 0.9955 - val_f1_score: 0.9294 - val_loss: 0.1960 - val_precision: 0.9399 - val_recall: 0.9196
# Epoch 99/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9845 - auc: 0.9973 - f1_score: 0.9529 - loss: 0.1572 - precision: 0.9625 - recall: 0.9438 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9285 - val_loss: 0.1954 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 100/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9847 - auc: 0.9979 - f1_score: 0.9548 - loss: 0.1428 - precision: 0.9619 - recall: 0.9453 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9291 - val_loss: 0.1948 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 101/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9818 - auc: 0.9976 - f1_score: 0.9447 - loss: 0.1535 - precision: 0.9548 - recall: 0.9352 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9291 - val_loss: 0.1941 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 102/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9830 - auc: 0.9974 - f1_score: 0.9485 - loss: 0.1565 - precision: 0.9573 - recall: 0.9399 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9292 - val_loss: 0.1938 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 103/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9819 - auc: 0.9975 - f1_score: 0.9452 - loss: 0.1537 - precision: 0.9539 - recall: 0.9370 - val_accuracy: 0.9763 - val_auc: 0.9956 - val_f1_score: 0.9280 - val_loss: 0.1933 - val_precision: 0.9379 - val_recall: 0.9186
# Epoch 104/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9832 - auc: 0.9976 - f1_score: 0.9496 - loss: 0.1502 - precision: 0.9567 - recall: 0.9417 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9292 - val_loss: 0.1930 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 105/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9841 - auc: 0.9971 - f1_score: 0.9520 - loss: 0.1539 - precision: 0.9609 - recall: 0.9432 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_f1_score: 0.9289 - val_loss: 0.1931 - val_precision: 0.9389 - val_recall: 0.9196
# Epoch 106/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9842 - auc: 0.9976 - f1_score: 0.9524 - loss: 0.1502 - precision: 0.9587 - recall: 0.9459 - val_accuracy: 0.9771 - val_auc: 0.9957 - val_f1_score: 0.9307 - val_loss: 0.1922 - val_precision: 0.9400 - val_recall: 0.9216
# Epoch 107/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9836 - auc: 0.9973 - f1_score: 0.9499 - loss: 0.1575 - precision: 0.9594 - recall: 0.9415 - val_accuracy: 0.9770 - val_auc: 0.9957 - val_f1_score: 0.9301 - val_loss: 0.1923 - val_precision: 0.9399 - val_recall: 0.9206
# Epoch 108/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9827 - auc: 0.9977 - f1_score: 0.9484 - loss: 0.1525 - precision: 0.9561 - recall: 0.9396 - val_accuracy: 0.9768 - val_auc: 0.9957 - val_f1_score: 0.9296 - val_loss: 0.1921 - val_precision: 0.9390 - val_recall: 0.9206
# Epoch 109/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9831 - auc: 0.9976 - f1_score: 0.9488 - loss: 0.1476 - precision: 0.9568 - recall: 0.9411 - val_accuracy: 0.9775 - val_auc: 0.9957 - val_f1_score: 0.9318 - val_loss: 0.1914 - val_precision: 0.9410 - val_recall: 0.9225
# Epoch 110/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9841 - auc: 0.9978 - f1_score: 0.9516 - loss: 0.1430 - precision: 0.9608 - recall: 0.9430 - val_accuracy: 0.9773 - val_auc: 0.9957 - val_f1_score: 0.9311 - val_loss: 0.1908 - val_precision: 0.9409 - val_recall: 0.9216
# Epoch 111/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9842 - auc: 0.9978 - f1_score: 0.9522 - loss: 0.1479 - precision: 0.9591 - recall: 0.9455 - val_accuracy: 0.9770 - val_auc: 0.9957 - val_f1_score: 0.9303 - val_loss: 0.1908 - val_precision: 0.9391 - val_recall: 0.9216
# Epoch 112/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9835 - auc: 0.9976 - f1_score: 0.9502 - loss: 0.1479 - precision: 0.9604 - recall: 0.9399 - val_accuracy: 0.9776 - val_auc: 0.9957 - val_f1_score: 0.9322 - val_loss: 0.1899 - val_precision: 0.9411 - val_recall: 0.9235
# Epoch 113/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9827 - auc: 0.9973 - f1_score: 0.9477 - loss: 0.1547 - precision: 0.9560 - recall: 0.9396 - val_accuracy: 0.9779 - val_auc: 0.9958 - val_f1_score: 0.9334 - val_loss: 0.1897 - val_precision: 0.9421 - val_recall: 0.9245
# Epoch 114/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9841 - auc: 0.9975 - f1_score: 0.9527 - loss: 0.1529 - precision: 0.9596 - recall: 0.9445 - val_accuracy: 0.9770 - val_auc: 0.9958 - val_f1_score: 0.9303 - val_loss: 0.1897 - val_precision: 0.9391 - val_recall: 0.9216
# Epoch 115/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9853 - auc: 0.9980 - f1_score: 0.9556 - loss: 0.1384 - precision: 0.9639 - recall: 0.9475 - val_accuracy: 0.9768 - val_auc: 0.9957 - val_f1_score: 0.9297 - val_loss: 0.1903 - val_precision: 0.9373 - val_recall: 0.9225
# Epoch 116/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9842 - auc: 0.9981 - f1_score: 0.9526 - loss: 0.1396 - precision: 0.9603 - recall: 0.9444 - val_accuracy: 0.9775 - val_auc: 0.9958 - val_f1_score: 0.9317 - val_loss: 0.1888 - val_precision: 0.9392 - val_recall: 0.9245
# Epoch 117/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9860 - auc: 0.9982 - f1_score: 0.9581 - loss: 0.1315 - precision: 0.9651 - recall: 0.9504 - val_accuracy: 0.9775 - val_auc: 0.9958 - val_f1_score: 0.9316 - val_loss: 0.1884 - val_precision: 0.9410 - val_recall: 0.9225
# Epoch 118/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.9852 - auc: 0.9982 - f1_score: 0.9544 - loss: 0.1339 - precision: 0.9623 - recall: 0.9481 - val_accuracy: 0.9775 - val_auc: 0.9958 - val_f1_score: 0.9318 - val_loss: 0.1880 - val_precision: 0.9392 - val_recall: 0.9245
# Epoch 119/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9849 - auc: 0.9979 - f1_score: 0.9543 - loss: 0.1416 - precision: 0.9617 - recall: 0.9470 - val_accuracy: 0.9778 - val_auc: 0.9958 - val_f1_score: 0.9327 - val_loss: 0.1872 - val_precision: 0.9411 - val_recall: 0.9245
# Epoch 120/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9849 - auc: 0.9977 - f1_score: 0.9541 - loss: 0.1433 - precision: 0.9630 - recall: 0.9455 - val_accuracy: 0.9776 - val_auc: 0.9959 - val_f1_score: 0.9323 - val_loss: 0.1872 - val_precision: 0.9411 - val_recall: 0.9235
# Epoch 121/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9855 - auc: 0.9983 - f1_score: 0.9563 - loss: 0.1325 - precision: 0.9644 - recall: 0.9482 - val_accuracy: 0.9776 - val_auc: 0.9959 - val_f1_score: 0.9321 - val_loss: 0.1870 - val_precision: 0.9411 - val_recall: 0.9235
# Epoch 122/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9847 - auc: 0.9980 - f1_score: 0.9536 - loss: 0.1375 - precision: 0.9602 - recall: 0.9473 - val_accuracy: 0.9781 - val_auc: 0.9959 - val_f1_score: 0.9336 - val_loss: 0.1863 - val_precision: 0.9421 - val_recall: 0.9255
# Epoch 123/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9849 - auc: 0.9985 - f1_score: 0.9542 - loss: 0.1286 - precision: 0.9620 - recall: 0.9470 - val_accuracy: 0.9779 - val_auc: 0.9959 - val_f1_score: 0.9331 - val_loss: 0.1860 - val_precision: 0.9421 - val_recall: 0.9245
# Epoch 124/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9844 - auc: 0.9979 - f1_score: 0.9529 - loss: 0.1403 - precision: 0.9609 - recall: 0.9452 - val_accuracy: 0.9778 - val_auc: 0.9959 - val_f1_score: 0.9329 - val_loss: 0.1859 - val_precision: 0.9411 - val_recall: 0.9245
# Epoch 125/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9857 - auc: 0.9969 - f1_score: 0.9573 - loss: 0.1464 - precision: 0.9634 - recall: 0.9506 - val_accuracy: 0.9776 - val_auc: 0.9959 - val_f1_score: 0.9319 - val_loss: 0.1856 - val_precision: 0.9411 - val_recall: 0.9235
# Epoch 126/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9874 - auc: 0.9986 - f1_score: 0.9619 - loss: 0.1255 - precision: 0.9682 - recall: 0.9559 - val_accuracy: 0.9778 - val_auc: 0.9959 - val_f1_score: 0.9327 - val_loss: 0.1852 - val_precision: 0.9411 - val_recall: 0.9245
# Epoch 127/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9878 - auc: 0.9984 - f1_score: 0.9633 - loss: 0.1239 - precision: 0.9708 - recall: 0.9558 - val_accuracy: 0.9778 - val_auc: 0.9959 - val_f1_score: 0.9328 - val_loss: 0.1858 - val_precision: 0.9402 - val_recall: 0.9255
# Epoch 128/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9850 - auc: 0.9974 - f1_score: 0.9547 - loss: 0.1437 - precision: 0.9597 - recall: 0.9499 - val_accuracy: 0.9778 - val_auc: 0.9959 - val_f1_score: 0.9329 - val_loss: 0.1849 - val_precision: 0.9402 - val_recall: 0.9255
# Epoch 129/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9856 - auc: 0.9978 - f1_score: 0.9567 - loss: 0.1306 - precision: 0.9653 - recall: 0.9480 - val_accuracy: 0.9781 - val_auc: 0.9959 - val_f1_score: 0.9338 - val_loss: 0.1848 - val_precision: 0.9421 - val_recall: 0.9255
# Epoch 130/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9860 - auc: 0.9981 - f1_score: 0.9579 - loss: 0.1341 - precision: 0.9653 - recall: 0.9503 - val_accuracy: 0.9783 - val_auc: 0.9959 - val_f1_score: 0.9342 - val_loss: 0.1845 - val_precision: 0.9431 - val_recall: 0.9255
# Epoch 131/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9849 - auc: 0.9982 - f1_score: 0.9545 - loss: 0.1351 - precision: 0.9613 - recall: 0.9478 - val_accuracy: 0.9784 - val_auc: 0.9959 - val_f1_score: 0.9348 - val_loss: 0.1843 - val_precision: 0.9440 - val_recall: 0.9255
# Epoch 132/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9854 - auc: 0.9981 - f1_score: 0.9570 - loss: 0.1308 - precision: 0.9628 - recall: 0.9491 - val_accuracy: 0.9779 - val_auc: 0.9960 - val_f1_score: 0.9332 - val_loss: 0.1840 - val_precision: 0.9412 - val_recall: 0.9255
# Epoch 133/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9854 - auc: 0.9982 - f1_score: 0.9557 - loss: 0.1311 - precision: 0.9621 - recall: 0.9499 - val_accuracy: 0.9783 - val_auc: 0.9959 - val_f1_score: 0.9340 - val_loss: 0.1839 - val_precision: 0.9422 - val_recall: 0.9265
# Epoch 134/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9837 - auc: 0.9980 - f1_score: 0.9506 - loss: 0.1368 - precision: 0.9580 - recall: 0.9434 - val_accuracy: 0.9783 - val_auc: 0.9960 - val_f1_score: 0.9339 - val_loss: 0.1839 - val_precision: 0.9431 - val_recall: 0.9255
# Epoch 135/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9856 - auc: 0.9979 - f1_score: 0.9563 - loss: 0.1320 - precision: 0.9631 - recall: 0.9499 - val_accuracy: 0.9786 - val_auc: 0.9960 - val_f1_score: 0.9353 - val_loss: 0.1831 - val_precision: 0.9441 - val_recall: 0.9265
# Epoch 136/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9862 - auc: 0.9980 - f1_score: 0.9578 - loss: 0.1302 - precision: 0.9658 - recall: 0.9506 - val_accuracy: 0.9788 - val_auc: 0.9960 - val_f1_score: 0.9355 - val_loss: 0.1825 - val_precision: 0.9450 - val_recall: 0.9265
# Epoch 137/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9861 - auc: 0.9987 - f1_score: 0.9576 - loss: 0.1189 - precision: 0.9646 - recall: 0.9514 - val_accuracy: 0.9786 - val_auc: 0.9960 - val_f1_score: 0.9351 - val_loss: 0.1817 - val_precision: 0.9423 - val_recall: 0.9284
# Epoch 138/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9874 - auc: 0.9979 - f1_score: 0.9616 - loss: 0.1273 - precision: 0.9684 - recall: 0.9553 - val_accuracy: 0.9784 - val_auc: 0.9960 - val_f1_score: 0.9347 - val_loss: 0.1826 - val_precision: 0.9431 - val_recall: 0.9265
# Epoch 139/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9883 - auc: 0.9987 - f1_score: 0.9648 - loss: 0.1186 - precision: 0.9699 - recall: 0.9596 - val_accuracy: 0.9788 - val_auc: 0.9961 - val_f1_score: 0.9358 - val_loss: 0.1815 - val_precision: 0.9432 - val_recall: 0.9284
# Epoch 140/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9871 - auc: 0.9982 - f1_score: 0.9608 - loss: 0.1268 - precision: 0.9675 - recall: 0.9545 - val_accuracy: 0.9791 - val_auc: 0.9960 - val_f1_score: 0.9368 - val_loss: 0.1816 - val_precision: 0.9451 - val_recall: 0.9284
# Epoch 141/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9862 - auc: 0.9979 - f1_score: 0.9582 - loss: 0.1324 - precision: 0.9661 - recall: 0.9505 - val_accuracy: 0.9791 - val_auc: 0.9961 - val_f1_score: 0.9366 - val_loss: 0.1810 - val_precision: 0.9451 - val_recall: 0.9284
# Epoch 142/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9880 - auc: 0.9986 - f1_score: 0.9638 - loss: 0.1183 - precision: 0.9697 - recall: 0.9582 - val_accuracy: 0.9789 - val_auc: 0.9961 - val_f1_score: 0.9360 - val_loss: 0.1809 - val_precision: 0.9442 - val_recall: 0.9284
# Epoch 143/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9873 - auc: 0.9987 - f1_score: 0.9620 - loss: 0.1203 - precision: 0.9670 - recall: 0.9566 - val_accuracy: 0.9791 - val_auc: 0.9961 - val_f1_score: 0.9368 - val_loss: 0.1800 - val_precision: 0.9451 - val_recall: 0.9284
# Epoch 144/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9865 - auc: 0.9985 - f1_score: 0.9595 - loss: 0.1182 - precision: 0.9642 - recall: 0.9546 - val_accuracy: 0.9791 - val_auc: 0.9961 - val_f1_score: 0.9367 - val_loss: 0.1800 - val_precision: 0.9451 - val_recall: 0.9284
# Epoch 145/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9873 - auc: 0.9984 - f1_score: 0.9615 - loss: 0.1235 - precision: 0.9685 - recall: 0.9547 - val_accuracy: 0.9791 - val_auc: 0.9961 - val_f1_score: 0.9366 - val_loss: 0.1798 - val_precision: 0.9451 - val_recall: 0.9284
# Epoch 146/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9868 - auc: 0.9986 - f1_score: 0.9604 - loss: 0.1161 - precision: 0.9669 - recall: 0.9533 - val_accuracy: 0.9789 - val_auc: 0.9961 - val_f1_score: 0.9360 - val_loss: 0.1797 - val_precision: 0.9442 - val_recall: 0.9284
# Epoch 147/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9865 - auc: 0.9987 - f1_score: 0.9600 - loss: 0.1178 - precision: 0.9656 - recall: 0.9532 - val_accuracy: 0.9788 - val_auc: 0.9961 - val_f1_score: 0.9356 - val_loss: 0.1800 - val_precision: 0.9450 - val_recall: 0.9265
# Epoch 148/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9872 - auc: 0.9984 - f1_score: 0.9614 - loss: 0.1201 - precision: 0.9679 - recall: 0.9549 - val_accuracy: 0.9788 - val_auc: 0.9961 - val_f1_score: 0.9356 - val_loss: 0.1795 - val_precision: 0.9441 - val_recall: 0.9275
# Epoch 149/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9868 - auc: 0.9983 - f1_score: 0.9601 - loss: 0.1236 - precision: 0.9670 - recall: 0.9531 - val_accuracy: 0.9792 - val_auc: 0.9961 - val_f1_score: 0.9371 - val_loss: 0.1795 - val_precision: 0.9452 - val_recall: 0.9294
# Epoch 150/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9864 - auc: 0.9985 - f1_score: 0.9589 - loss: 0.1228 - precision: 0.9638 - recall: 0.9539 - val_accuracy: 0.9792 - val_auc: 0.9961 - val_f1_score: 0.9373 - val_loss: 0.1798 - val_precision: 0.9452 - val_recall: 0.9294
# Epoch 151/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9876 - auc: 0.9986 - f1_score: 0.9627 - loss: 0.1131 - precision: 0.9681 - recall: 0.9573 - val_accuracy: 0.9791 - val_auc: 0.9961 - val_f1_score: 0.9367 - val_loss: 0.1793 - val_precision: 0.9442 - val_recall: 0.9294
# Epoch 152/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9861 - auc: 0.9985 - f1_score: 0.9580 - loss: 0.1223 - precision: 0.9639 - recall: 0.9524 - val_accuracy: 0.9794 - val_auc: 0.9962 - val_f1_score: 0.9376 - val_loss: 0.1788 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 153/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9859 - auc: 0.9985 - f1_score: 0.9570 - loss: 0.1238 - precision: 0.9651 - recall: 0.9496 - val_accuracy: 0.9794 - val_auc: 0.9962 - val_f1_score: 0.9376 - val_loss: 0.1786 - val_precision: 0.9461 - val_recall: 0.9294
# Epoch 154/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9878 - auc: 0.9987 - f1_score: 0.9634 - loss: 0.1138 - precision: 0.9684 - recall: 0.9579 - val_accuracy: 0.9792 - val_auc: 0.9962 - val_f1_score: 0.9373 - val_loss: 0.1784 - val_precision: 0.9452 - val_recall: 0.9294
# Epoch 155/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9866 - auc: 0.9983 - f1_score: 0.9596 - loss: 0.1214 - precision: 0.9650 - recall: 0.9543 - val_accuracy: 0.9792 - val_auc: 0.9962 - val_f1_score: 0.9371 - val_loss: 0.1777 - val_precision: 0.9452 - val_recall: 0.9294
# Epoch 156/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9864 - auc: 0.9984 - f1_score: 0.9592 - loss: 0.1250 - precision: 0.9638 - recall: 0.9540 - val_accuracy: 0.9792 - val_auc: 0.9962 - val_f1_score: 0.9370 - val_loss: 0.1781 - val_precision: 0.9452 - val_recall: 0.9294
# Epoch 157/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9901 - auc: 0.9989 - f1_score: 0.9695 - loss: 0.1036 - precision: 0.9749 - recall: 0.9655 - val_accuracy: 0.9791 - val_auc: 0.9962 - val_f1_score: 0.9364 - val_loss: 0.1775 - val_precision: 0.9442 - val_recall: 0.9294
# Epoch 158/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9868 - auc: 0.9984 - f1_score: 0.9601 - loss: 0.1218 - precision: 0.9662 - recall: 0.9543 - val_accuracy: 0.9794 - val_auc: 0.9962 - val_f1_score: 0.9376 - val_loss: 0.1771 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 159/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9878 - auc: 0.9984 - f1_score: 0.9638 - loss: 0.1148 - precision: 0.9680 - recall: 0.9586 - val_accuracy: 0.9786 - val_auc: 0.9962 - val_f1_score: 0.9352 - val_loss: 0.1782 - val_precision: 0.9432 - val_recall: 0.9275
# Epoch 160/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9875 - auc: 0.9981 - f1_score: 0.9627 - loss: 0.1157 - precision: 0.9681 - recall: 0.9566 - val_accuracy: 0.9794 - val_auc: 0.9962 - val_f1_score: 0.9379 - val_loss: 0.1772 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 161/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9877 - auc: 0.9986 - f1_score: 0.9625 - loss: 0.1137 - precision: 0.9677 - recall: 0.9581 - val_accuracy: 0.9796 - val_auc: 0.9962 - val_f1_score: 0.9383 - val_loss: 0.1769 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 162/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9906 - auc: 0.9988 - f1_score: 0.9719 - loss: 0.1085 - precision: 0.9765 - recall: 0.9671 - val_accuracy: 0.9796 - val_auc: 0.9962 - val_f1_score: 0.9381 - val_loss: 0.1771 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 163/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9863 - auc: 0.9988 - f1_score: 0.9577 - loss: 0.1119 - precision: 0.9648 - recall: 0.9526 - val_accuracy: 0.9794 - val_auc: 0.9962 - val_f1_score: 0.9377 - val_loss: 0.1766 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 164/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9882 - auc: 0.9989 - f1_score: 0.9650 - loss: 0.1053 - precision: 0.9694 - recall: 0.9595 - val_accuracy: 0.9797 - val_auc: 0.9962 - val_f1_score: 0.9388 - val_loss: 0.1769 - val_precision: 0.9471 - val_recall: 0.9304
# Epoch 165/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9884 - auc: 0.9988 - f1_score: 0.9649 - loss: 0.1130 - precision: 0.9694 - recall: 0.9609 - val_accuracy: 0.9796 - val_auc: 0.9962 - val_f1_score: 0.9383 - val_loss: 0.1762 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 166/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9875 - auc: 0.9986 - f1_score: 0.9624 - loss: 0.1197 - precision: 0.9699 - recall: 0.9548 - val_accuracy: 0.9801 - val_auc: 0.9962 - val_f1_score: 0.9396 - val_loss: 0.1763 - val_precision: 0.9472 - val_recall: 0.9324
# Epoch 167/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9886 - auc: 0.9988 - f1_score: 0.9656 - loss: 0.1106 - precision: 0.9718 - recall: 0.9594 - val_accuracy: 0.9794 - val_auc: 0.9963 - val_f1_score: 0.9375 - val_loss: 0.1753 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 168/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9884 - auc: 0.9988 - f1_score: 0.9651 - loss: 0.1100 - precision: 0.9699 - recall: 0.9603 - val_accuracy: 0.9797 - val_auc: 0.9962 - val_f1_score: 0.9387 - val_loss: 0.1761 - val_precision: 0.9471 - val_recall: 0.9304
# Epoch 169/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9877 - auc: 0.9988 - f1_score: 0.9631 - loss: 0.1097 - precision: 0.9691 - recall: 0.9566 - val_accuracy: 0.9797 - val_auc: 0.9962 - val_f1_score: 0.9388 - val_loss: 0.1761 - val_precision: 0.9462 - val_recall: 0.9314
# Epoch 170/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9886 - auc: 0.9990 - f1_score: 0.9653 - loss: 0.1040 - precision: 0.9703 - recall: 0.9608 - val_accuracy: 0.9796 - val_auc: 0.9963 - val_f1_score: 0.9381 - val_loss: 0.1746 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 171/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9883 - auc: 0.9989 - f1_score: 0.9647 - loss: 0.1061 - precision: 0.9690 - recall: 0.9603 - val_accuracy: 0.9794 - val_auc: 0.9963 - val_f1_score: 0.9377 - val_loss: 0.1754 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 172/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9880 - auc: 0.9987 - f1_score: 0.9637 - loss: 0.1085 - precision: 0.9684 - recall: 0.9591 - val_accuracy: 0.9796 - val_auc: 0.9963 - val_f1_score: 0.9382 - val_loss: 0.1751 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 173/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9887 - auc: 0.9988 - f1_score: 0.9661 - loss: 0.1078 - precision: 0.9707 - recall: 0.9610 - val_accuracy: 0.9797 - val_auc: 0.9963 - val_f1_score: 0.9386 - val_loss: 0.1743 - val_precision: 0.9462 - val_recall: 0.9314
# Epoch 174/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9884 - auc: 0.9987 - f1_score: 0.9649 - loss: 0.1096 - precision: 0.9691 - recall: 0.9610 - val_accuracy: 0.9796 - val_auc: 0.9963 - val_f1_score: 0.9381 - val_loss: 0.1742 - val_precision: 0.9462 - val_recall: 0.9304
# Epoch 175/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9880 - auc: 0.9983 - f1_score: 0.9640 - loss: 0.1126 - precision: 0.9687 - recall: 0.9592 - val_accuracy: 0.9797 - val_auc: 0.9963 - val_f1_score: 0.9387 - val_loss: 0.1736 - val_precision: 0.9462 - val_recall: 0.9314
# Epoch 176/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9880 - auc: 0.9988 - f1_score: 0.9640 - loss: 0.1086 - precision: 0.9694 - recall: 0.9583 - val_accuracy: 0.9794 - val_auc: 0.9963 - val_f1_score: 0.9376 - val_loss: 0.1742 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 177/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9887 - auc: 0.9990 - f1_score: 0.9658 - loss: 0.1039 - precision: 0.9701 - recall: 0.9619 - val_accuracy: 0.9794 - val_auc: 0.9963 - val_f1_score: 0.9376 - val_loss: 0.1739 - val_precision: 0.9452 - val_recall: 0.9304
# Epoch 178/300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9885 - auc: 0.9989 - f1_score: 0.9652 - loss: 0.1106 - precision: 0.9717 - recall: 0.9589 - val_accuracy: 0.9801 - val_auc: 0.9963 - val_f1_score: 0.9396 - val_loss: 0.1740 - val_precision: 0.9472 - val_recall: 0.9324

# %% [markdown]
# Result

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 97.66%

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt 
def Train_Val_plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):
    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(20, 5))
    fig.suptitle("VISUALIZE THE PERFORMANCE MATRICS")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1 Score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 Score')
    ax5.legend(['training', 'validation'])
    plt.show()

# %%
Train_Val_plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        Buras       0.93      0.92      0.93       170
#      Dangkot       0.90      0.86      0.88       170
#        Gogos       0.95      0.96      0.95       170
#     Kapurung       0.95      0.96      0.95       170
#        Sokko       0.90      0.93      0.92       170
#    Sop Konro       0.93      0.94      0.93       170
#
#     accuracy                           0.93      1020
#    macro avg       0.93      0.93      0.93      1020
# weighted avg       0.93      0.93      0.93      1020

# %%
# Import required libraries
import seaborn as sns

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_images.class_indices.keys(), yticklabels=test_images.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Saving the model
model.save('EfficientNetB0(8).h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Saving the model
# ----> 2 model.save('EfficientNetB0(8).h5')
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File c:\Program Files\Python311\Lib\site-packages\h5py\_hl\dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %% [markdown]
# Deteksi

# %%
import numpy as np
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.mobilenet_v2 import preprocess_input
import matplotlib.pyplot as plt

# Load the custom MobileNetV2 model
model = load_model("D:\Kuliah Semester 6\Jurnal\Materi\CNN\Codingan\EfficientNetB0-8.h5")

# Define the class names
class_names = ['Buras', 'Dangkot', 'Gogos', 'Kapurung', 'Sokko', 'Sop Konro']

# Define the path to your image
image_path = r"D:\Kuliah Semester 6\Jurnal\Materi\CNN\Split_dataset\test\Sokko\SOKKO_91.jpg"

# Load and preprocess the image
img = image.load_img(image_path, target_size=(224, 224))  # Sesuaikan ukuran dengan ukuran input model Anda
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make prediction
preds = model.predict(x)

# Check the shape of the predictions
print("Predictions shape:", preds.shape)

# Get the index of the highest probability prediction
pred_index = np.argmax(preds)

# Initialize the predicted class variable
predicted_class = "Predicted index is out of range"

# Check if pred_index is within the range of class_names
if pred_index < len(class_names):
    # Get the predicted class label
    predicted_class = class_names[pred_index]

# Print the predicted class label
print("Predicted class:", predicted_class)

# Display the image along with the predicted class
plt.imshow(image.load_img(image_path))
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predictions shape: (1, 6)
# Predicted class: Kapurung
